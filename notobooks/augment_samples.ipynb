# %%
import pandas as pd
import numpy as np
import nltk
from collections import Counter
from nltk.corpus import wordnet
from textblob import Word
import random

from nltk.corpus import stopwords
stops = stopwords.words('english')
pd.set_option('max_colwidth',80)

# %%
df_10k = pd.read_table('samples/training_10k.tsv', sep='\t', encoding='utf-8',
                     names=['is_duplicate','question1', 'question2', 'id'])
df_50k = pd.read_table('samples/training_50k.tsv', sep='\t', encoding='utf-8',
                     names=['is_duplicate','question1', 'question2', 'id'])
df_5k = pd.read_table('samples/training_5k.tsv', sep='\t', encoding='utf-8',
                     names=['is_duplicate','question1', 'question2', 'id'])
df_15k = pd.read_table('samples/training_15k.tsv', sep='\t', encoding='utf-8',
                     names=['is_duplicate','question1', 'question2', 'id'])
df_20k = pd.read_table('samples/training_20k.tsv', sep='\t', encoding='utf-8',
                     names=['is_duplicate','question1', 'question2', 'id'])
df_25k = pd.read_table('samples/training_25k.tsv', sep='\t', encoding='utf-8',
                     names=['is_duplicate','question1', 'question2', 'id'])
df_30k = pd.read_table('samples/training_30k.tsv', sep='\t', encoding='utf-8',
                     names=['is_duplicate','question1', 'question2', 'id'])

# %%
ask_5k = pd.read_table('samples/ask_5k.tsv', sep='\t', encoding='utf-8',
                     names=['is_duplicate','question1', 'question2', 'id'])
ask_10k = pd.read_table('samples/ask_10k.tsv', sep='\t', encoding='utf-8',
                     names=['is_duplicate','question1', 'question2', 'id'])
ask_15k = pd.read_table('samples/ask_15k.tsv', sep='\t', encoding='utf-8',
                     names=['is_duplicate','question1', 'question2', 'id'])
ask_full = pd.read_table('new_train.tsv', sep='\t', encoding='utf-8',
                     names=['is_duplicate','question1', 'question2', 'qid'])

# %%
def preprocess(df):
    df["question1"] = df['question1'].str.replace('[^\w\s]','')
    df["question2"] = df['question2'].str.replace('[^\w\s]','')
    print("Preprocess done!")
    return df

def features(df):
    df['q1_lemma'] = df['question1'].apply(lemmatize_text)
    df['q2_lemma'] = df['question2'].apply(lemmatize_text)
    df['word_overlap'] = df.apply( word_match, axis=1, raw=True)
    df['word_overlap_score'] = df.apply(word_match_share, axis=1, raw=True)
    df['q1_n_words'] = df['question1'].apply(lambda row: len(row.split(" ")))
    df['q2_n_words'] = df['question2'].apply(lambda row: len(row.split(" ")))
    print("Features done!")
    return df

def heuristic(df):
    overlap = df[(df['word_overlap_score'] > 0.6)]
    overlap = overlap[['is_duplicate','question2', 'question1', 'qid']]
    overlap.rename(columns={'question2':'question1',
                                'question1':'question2'}, inplace=True)

    low_overlap = df[(df['word_overlap_score'] < 0.4) & (df_10k['is_duplicate'] == 1)]
    low_overlap = low_overlap[['is_duplicate','question2', 'question1', 'qid']]
    low_overlap.rename(columns={'question2':'question1',
                                'question1':'question2'}, inplace=True)
    print(overlap.count()[0])
    print(low_overlap.count()[0])
    heuristic = pd.concat([df[['is_duplicate','question1', 'question2', 'qid']], overlap, low_overlap])
    heuristic.reset_index(inplace=True, drop=True)
    print("Heuristic done!")
    return heuristic

def replace_sysnonyms(text):
    line = text.strip()
    words = line.split(" ")
    output = list()
    for word_str in words:
        word_obj = Word(word_str)
        if len(word_str) > 3 and len(word_obj.synsets) > 0:
            synset = word_obj.synsets[0]
            lemma = random.choice(synset.lemma_names())
            output.append(lemma.replace('_', ' '))
        else:
            output.append(word_str)
    new_text =  " ".join(output)
    return new_text

def synonyms(df):
    df['q1_synonym'] = df['question1'].apply(lambda x: replace_sysnonyms(x))
    df['q2_synonym'] = df['question2'].apply(lambda x: replace_sysnonyms(x))

    synonyms = df[['is_duplicate','q1_synonym', 'q2_synonym', 'qid']]
    synonyms.rename(columns={'q1_synonym':'question1',
                                'q2_synonym':'question2'}, inplace=True)
    df_syn = pd.concat([df[['is_duplicate','question1', 'question2', 'qid']], synonyms])
    df_syn.reset_index(inplace=True, drop=True)
    print("Synonyms done!")
    return df_syn

def reverse_order(df):
    reverse = df[['is_duplicate','question2', 'question1', 'qid']]
    reverse.rename(columns={'question2':'question1',
                                'question1':'question2'}, inplace=True)
    df = df[['is_duplicate','question1', 'question2', 'qid']]
    df_reverse = pd.concat([df, reverse])
    df_reverse.reset_index(inplace=True, drop=True)
    print("Reverse done!")
    return df_reverse

def write_to_file(reverse, heuristic, synonyms, size):
    h_file = 'samples/a_heuristic_%sk.tsv' % size
    s_file = 'samples/a_synonyms_%sk.tsv' % size
    r_file = 'samples/a_reverse_%sk.tsv' % size
    heuristic.to_csv(h_file,sep='\t', header=False, index=False, encoding='utf-8')
    synonyms.to_csv(s_file,sep='\t', header=False, index=False, encoding='utf-8')
    reverse.to_csv(r_file,sep='\t', header=False, index=False, encoding='utf-8')
    
def augment_data(df, size):
    df = preprocess(df)
    df = features(df)
    h = heuristic(df)
#     print(h.groupby('is_duplicate').count())
    syn = synonyms(df)
#     print(syn.groupby('is_duplicate').count())
    r = reverse_order(df)
#     print(r.groupby('is_duplicate').count())
    write_to_file(r,h,syn, size)
    print('aici')
    return r,h,syn

# %%
w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
lemmatizer = nltk.stem.WordNetLemmatizer()

def lemmatize_text(text):
    return [lemmatizer.lemmatize(w) for w in w_tokenizer.tokenize(text)]

def word_match(row):
    q1words = {}
    q2words = {}
    for word in str(row['q1_lemma']).lower().split():
        if word not in stops:
            q1words[word] = 1
    for word in str(row['q2_lemma']).lower().split():
        if word not in stops:
            q2words[word] = 1
    if len(q1words) == 0 or len(q2words) == 0:
        # The computer-generated chaff includes a few questions that are nothing but stopwords
        return 0
    shared_words_in_q1 = [w for w in q1words.keys() if w in q2words]
    R = len(shared_words_in_q1)
    return R

def word_match_share(row):
    q1words = {}
    q2words = {}
    for word in str(row['q1_lemma']).lower().split():
        if word not in stops:
            q1words[word] = 1
    for word in str(row['q2_lemma']).lower().split():
        if word not in stops:
            q2words[word] = 1
    if len(q1words) == 0 or len(q2words) == 0:
        # The computer-generated chaff includes a few questions that are nothing but stopwords
        return 0
    shared_words_in_q1 = [w for w in q1words.keys() if w in q2words]
    shared_words_in_q2 = [w for w in q2words.keys() if w in q1words]
    R = (len(shared_words_in_q1) + len(shared_words_in_q2))/(len(q1words) + len(q2words))
    return R

# %%
df_20k.isnull().sum()
df_20k.dropna(inplace=True)

# %%
# augment_data(df_5k, '5')
# augment_data(df_15k, '15')
# augment_data(df_20k, '20')
# augment_data(df_25k, '25')
# augment_data(df_20k, '30')
augment_data(df_10k, '10')

# %%
augment_data(ask_full, 'full')
# Out:
# Preprocess done!
# Features done!
# 52
# 3545
# Heuristic done!
# /Users/andrada/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3778: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# Synonyms done!
# Reverse done!
# aici
# (       is_duplicate  \
#  0                 0
#  1                 0
#  2                 1
#  3                 0
#  4                 1
#  5                 0
#  6                 0
#  7                 0
#  8                 1
#  9                 1
#  10                0
#  11                1
#  12                1
#  13                1
#  14                0
#  15                0
#  16                1
#  17                0
#  18                0
#  19                1
#  20                1
#  21                1
#  22                1
#  23                1
#  24                1
#  25                0
#  26                0
#  27                0
#  28                0
#  29                0
#  ...             ...
#  37970             0
#  37971             1
#  37972             0
#  37973             0
#  37974             1
#  37975             1
#  37976             1
#  37977             0
#  37978             0
#  37979             1
#  37980             1
#  37981             1
#  37982             1
#  37983             0
#  37984             0
#  37985             1
#  37986             0
#  37987             0
#  37988             0
#  37989             0
#  37990             0
#  37991             1
#  37992             0
#  37993             0
#  37994             0
#  37995             0
#  37996             0
#  37997             1
#  37998             0
#  37999             0
#
#                                                                               question1  \
#  0      volume muted around 0 20 level it was fine until 1310 i tested with pavucont...
#  1      how to get a netgear n300 adapter to work with ubuntu 1210 32bit no other tu...
#  2      how to make a disk image and restore from it later i a new linux user i rein...
#  3      rfkill list all not showing anything on the prompt i have dual installed ubu...
#  4      an upgrade from to is not unsupported with this tool error while upgrading a...
#  5      localhost problem i just installed lamp recently to study wordpress i instal...
#  6      reverting after installing lubuntu desktop i have installed ubuntu 1204 lts ...
#  7      hdd makes highpitched noise in windows but it is silent in ubuntu i was just...
#  8      how to fix the system is running in lowgraphics mode error note this is an a...
#  9      no ruby alternatives on 1104 1110 running fails 2 days ago january 15th 2012...
#  10     windows 8 not booting from grub 2 i have done a fair amount of research and ...
#  11     how do i install apache tomcat 7 troubleshooting with apache tomcat 7 steps ...
#  12     will it be possible to create appsgames in java se or java me on new ubuntu ...
#  13     trouble downloading updates due to a hash sum mismatch error when i check fo...
#  14     is there a desktop application for launchpadnet i was looking at the launchp...
#  15     issue with cp command when i was copying in i am not able to copy file in wi...
#  16     how do i upgrade to the development release aka ubuntu1 how do i upgrade to ...
#  17     is there an equivalent of the filebrowser applet for unity i really really m...
#  18     how long can my data stay on ubuntu one how long can my data stay on ubuntu ...
#  19     can not install ubuntu in virtualbox due to this kernel requires an x8664 cp...
#  20     what the difference between wubi and a regular alongside windows installatio...
#  21     how do i install ubuntu tv on my computer i have a media pc connected to my ...
#  22     how to copy paste from ubuntu virtualbox guest to windows host i am running ...
#  23     how to install software or upgrade from old unsupported release recently i h...
#  24     what are the benefits of a disk install vs wubi and can i migrate my setting...
#  25     firefox 401 crash intermittently and log out intermittently firefox 401 is c...
#  26     debug overheating issue on sony vaio pro 13 intel haswell i am using my sony...
#  27     sshfs transform_symlinks is broken i been using the same fstab command for a...
#  28     how to get data from a bluetooth device that is not visible i just bought a ...
#  29     sudo aptget install nautilusopenterminal does not work i newly installed ubu...
#  ...                                                                                ...
#  37970  minimal ubuntu 1204 for programming i new to linux i windows 7 installed sid...
#  37971  how to install oracle 10g on ubuntu 1110 is it possible to install oracle 10...
#  37972                                                     problems with libmysqlclient
#  37973  install command of terminal does nt work i a new user of ubuntu linux using ...
#  37974  hi i can not download anything from the software center nor can i get my upd...
#  37975  ubuntu usb on a mac i followed the instructions on ubuntucom to install ubun...
#  37976  monitor internet usage on ubuntu any idea how one would monitor internet usa...
#  37977  can i shrink gedit side panel my laptop screen is fairly small and gedit sid...
#  37978  unable to open php files on linux platform on ubuntu i copied over my files ...
#  37979  why is ubuntu redis package so old the latest release is 267 248 is now cons...
#  37980  where can i download ubuntu for intel i ca nt find an ubuntu installer to fo...
#  37981  restricting usb access i using ubuntu as a server with windows xp clients i ...
#  37982  installed nvidia driver got blank screen i having the problem with updating ...
#  37983  wifi function key not working on hp laptop i have an hp pavilion g71260 with...
#  37984  is there any way i can get scrybe gesture workflow technology scrybe is a pr...
#  37985  disable x server and gnome temporarily i need to execute some tests on a scr...
#  37986  i ca nt get my audio to work in ubuntu 1310 ca nt get speakers or headphones...
#  37987  e package synaptic has no installation candidate when trying to install syna...
#  37988  how do i prevent being kicked back to the login screen every time just finis...
#  37989  packages go missing after bootup and certain indicators do nt seem to instal...
#  37990  how do i setup freelan in ubuntu i can not find any tutorials online taking ...
#  37991  remove unused applications i running low on hard drive space and have been p...
#  37992  how to open shared folder in windows xp from nautilus i have fresh installed...
#  37993  hdmi issue with macbook pro 81 on ubuntu 1404 i have a macbook pro mbp 81 os...
#  37994  why there is no loginpassword for ubuntu one under system preferences what t...
#  37995  how to install mozilla central in linux i have downloaded the mozillacentral...
#  37996  bluez 519 ps4 controller i currently have a problem when pairing my computer...
#  37997                    regarding installation what should i do to solve this problem
#  37998  i ca nt open up url in hotot when i click on any link an error message pops ...
#  37999  update manager can not update due to dpkg error ubuntu 1210 i just downloade...
#
#                                                                               question2  \
#  0      fan noise of dell inspirion after ubuntu 1210 is installed alongside windows...
#  1      usb without a hard drive i running a dell latitude xt that the hardcover wen...
#  2      best way to backup a whole dualboot system i finally have my pc exactly the ...
#  3      how to configure mod_rewrite correctly while using cakephp this at first mig...
#  4      an upgrade from to is not supported with this tool i am trying to upgrade bu...
#  5      how do i read cpu temperatures on a phenom ii processor i am trying to measu...
#  6      how can i change the resolution seen by a bootloader in virtualbox i am usin...
#  7      how can i stop being prompted to unlock the keyring on boot found a solution...
#  8      system running in low graphics mode ubuntu 1204 when i boot my ubuntu 1204 i...
#  9      install ruby ubuntu with updatealternatives command i have 2 questions about...
#  10     upgrade wubi installed ubuntu 1204 lts to 1404 lts i installed ubuntu 1204 l...
#  11     install tomcat on ubuntu 1104 i tried installing tomcat on 1104 using but i ...
#  12     how can i write apps with java for ubuntu phone how can i write apps with ja...
#  13     unable to install anything from software center package issues in 1210 fresh...
#  14     ca nt use require all without order deny allow so i upgraded my ubuntu serve...
#  15     how to reset a vm to a previous snapshot i am running ubuntu virtual machine...
#  16     how to upgrade to the development version of ubuntu 1104 how do i upgrade ub...
#  17     software to _easily_ create hotspot at this link there is a tricky and not a...
#  18     system runs unusably slow everything was running fine until i installed a ch...
#  19     how can i run ubuntu via my vm i trying to install ubuntu 1204 to run in vir...
#  20     will installing ubuntu using wubi erase windows i have an hp laptop with 2 p...
#  21     how do install ubuntu tv on 1204 all the guides for installing ubuntu tv see...
#  22     copy from main system and paste in vbox how can i copy the information from ...
#  23     are existing updates available after end of support i am using ubuntu 1104 a...
#  24     1 or 2 partitions for 2 opsystems windows 7 ubuntu what is recommended insta...
#  25             how to compile source code from a tarball please explain in an easy way
#  26     web browser unable to open any pages while any other app is downloading at f...
#  27     how to change a dconf setting for customized live cd i am creating a live cd...
#  28     ubuntu 1204 lts no longer able to boot normally until recently i was able to...
#  29     i did somethings with mountmanager and i have some small problems i tried to...
#  ...                                                                                ...
#  37970  connections to ubuntu server running on ec2 i have a ubuntu ec2 with its def...
#  37971  how to install oracle10g i want to install oracle10g on my ubuntu 1110 serve...
#  37972  how do i install itunes on ubuntu i tried different ways to install itunes b...
#  37973  the purpose of updating after adding a ppa repository when adding a ppa repo...
#  37974  how do i fix a problem with mergelist or status file could not be parsed err...
#  37975  how do i get my mac to boot from an ubuntu usb key if you select usb and mac...
#  37976  how can you monitor internet download usage some broadband providers impose ...
#  37977  how to create a systemwide environmental variable i want to set an environme...
#  37978  slow bash tab completion my bash shell tab completion is very slow usually t...
#  37979  why do nt the ubuntu repositories have the latest versions of software why a...
#  37980  how do i install ubuntu i would like to see a full howto on how to install u...
#  37981  how do i restrict usb access i am the system administrator on a network usin...
#  37982  my computer boots to a black screen what options do i have to fix it i am tr...
#  37983  unable to login to steam steam is having trouble connecting to the servers s...
#  37984  unity not supported on an hp pavillion g6 i installed ubuntu 1104 on my new ...
#  37985  how do i stop gui i need to enter the command line alone with no gui to inst...
#  37986  swap partition not recognized the disk drive with uuid is not ready yet or n...
#  37987  rsync permission issues via ssh i am backing up a networked server via ssh u...
#  37988  virtualbox does nt work with a real partition so i followed the instructions...
#  37989  gui tools for apache are there any gui tools for configuring and monitoring ...
#  37990  e unable to locate package bfgminer i recently set up cubieboard with linaro...
#  37991  how do i free up disk space my ubuntu cloud server has left only 900mb of di...
#  37992  install will not proceed ok so i am very much new to linux and i have been t...
#  37993  keyboard language self switches i on 1310 i have an italian layout and somet...
#  37994  connection refused when i transfering data from dell laptop to lenovo laptop...
#  37995  how can i fix my xvinfo how can i fix my x serverdriver additional info foll...
#  37996  list python class properties i would like to get list of python class proper...
#  37997  permission denied are you root i get this error whenever i try to install pr...
#  37998  is it safe to install the nvidiacurrent driver and then have this hdd in ano...
#  37999  using in mkdir i just want to know how do i use with command i was trying to...
#
#           qid
#  0      22575
#  1      20244
#  2      13802
#  3      17018
#  4      10400
#  5       1217
#  6       6008
#  7        105
#  8       1936
#  9       5120
#  10     19768
#  11      6610
#  12      9950
#  13      8804
#  14     12129
#  15     11048
#  16     10566
#  17     23144
#  18     17803
#  19      8280
#  20      2439
#  21     13024
#  22      6068
#  23      2330
#  24     10054
#  25     22980
#  26      1860
#  27     14624
#  28      2759
#  29     18267
#  ...      ...
#  37970   6134
#  37971   5179
#  37972   7395
#  37973  15736
#  37974  12512
#  37975  12199
#  37976   7824
#  37977   1219
#  37978   1135
#  37979  10943
#  37980   5794
#  37981  10799
#  37982   8469
#  37983  18433
#  37984  15392
#  37985   7661
#  37986   5999
#  37987   3700
#  37988   9619
#  37989  13469
#  37990    776
#  37991  12610
#  37992     95
#  37993  17624
#  37994    726
#  37995  11441
#  37996    597
#  37997   3051
#  37998    515
#  37999    712
#
#  [38000 rows x 4 columns],        is_duplicate  \
#  0                 0
#  1                 0
#  2                 1
#  3                 0
#  4                 1
#  5                 0
#  6                 0
#  7                 0
#  8                 1
#  9                 1
#  10                0
#  11                1
#  12                1
#  13                1
#  14                0
#  15                0
#  16                1
#  17                0
#  18                0
#  19                1
#  20                1
#  21                1
#  22                1
#  23                1
#  24                1
#  25                0
#  26                0
#  27                0
#  28                0
#  29                0
#  ...             ...
#  22567             1
#  22568             0
#  22569             0
#  22570             0
#  22571             1
#  22572             0
#  22573             1
#  22574             0
#  22575             1
#  22576             1
#  22577             0
#  22578             0
#  22579             1
#  22580             0
#  22581             1
#  22582             0
#  22583             0
#  22584             0
#  22585             1
#  22586             0
#  22587             0
#  22588             0
#  22589             1
#  22590             1
#  22591             0
#  22592             0
#  22593             1
#  22594             1
#  22595             1
#  22596             1
#
#                                                                               question1  \
#  0      volume muted around 0 20 level it was fine until 1310 i tested with pavucont...
#  1      how to get a netgear n300 adapter to work with ubuntu 1210 32bit no other tu...
#  2      how to make a disk image and restore from it later i a new linux user i rein...
#  3      rfkill list all not showing anything on the prompt i have dual installed ubu...
#  4      an upgrade from to is not unsupported with this tool error while upgrading a...
#  5      localhost problem i just installed lamp recently to study wordpress i instal...
#  6      reverting after installing lubuntu desktop i have installed ubuntu 1204 lts ...
#  7      hdd makes highpitched noise in windows but it is silent in ubuntu i was just...
#  8      how to fix the system is running in lowgraphics mode error note this is an a...
#  9      no ruby alternatives on 1104 1110 running fails 2 days ago january 15th 2012...
#  10     windows 8 not booting from grub 2 i have done a fair amount of research and ...
#  11     how do i install apache tomcat 7 troubleshooting with apache tomcat 7 steps ...
#  12     will it be possible to create appsgames in java se or java me on new ubuntu ...
#  13     trouble downloading updates due to a hash sum mismatch error when i check fo...
#  14     is there a desktop application for launchpadnet i was looking at the launchp...
#  15     issue with cp command when i was copying in i am not able to copy file in wi...
#  16     how do i upgrade to the development release aka ubuntu1 how do i upgrade to ...
#  17     is there an equivalent of the filebrowser applet for unity i really really m...
#  18     how long can my data stay on ubuntu one how long can my data stay on ubuntu ...
#  19     can not install ubuntu in virtualbox due to this kernel requires an x8664 cp...
#  20     what the difference between wubi and a regular alongside windows installatio...
#  21     how do i install ubuntu tv on my computer i have a media pc connected to my ...
#  22     how to copy paste from ubuntu virtualbox guest to windows host i am running ...
#  23     how to install software or upgrade from old unsupported release recently i h...
#  24     what are the benefits of a disk install vs wubi and can i migrate my setting...
#  25     firefox 401 crash intermittently and log out intermittently firefox 401 is c...
#  26     debug overheating issue on sony vaio pro 13 intel haswell i am using my sony...
#  27     sshfs transform_symlinks is broken i been using the same fstab command for a...
#  28     how to get data from a bluetooth device that is not visible i just bought a ...
#  29     sudo aptget install nautilusopenterminal does not work i newly installed ubu...
#  ...                                                                                ...
#  22567  will ubuntu work smoothly with these computer specifications mainly i want a...
#  22568  ralink rt2790 or maybe a rt2860 detected as two different chipsets ca nt con...
#  22569  micro sd card write protected fat32 i have tried this solution and it doesnt...
#  22570  how to show hidden folders in 1404 ubuntu how do you show a hidden folder sp...
#  22571  why do nt my icons change in unity i recently upgraded to ubuntu 1110 and it...
#  22572  ubuntu frozen every time when memory usage over 80 ubuntu frozen every time ...
#  22573  ubuntu update manager is showing an error message the error message is as fo...
#  22574  synaptic installs firefox when uninstalling chromium i use iron so i wanted ...
#  22575  what is the command line for skype installation i am wondering what the comm...
#  22576  who owns ubuntu and the ownership of ubuntu as a going concern as i read mar...
#  22577  ubuntu based os wo nt boot i have tried installing lubuntu xubuntu kubuntu a...
#  22578  is it possible to use the volume notifications from gnome shell in xfce i so...
#  22579  how to install ubuntu with windows 8 i am using windows 8i wanted to install...
#  22580  problem with bash script not found i had a script which was running fine but...
#  22581  how to get package when ubuntu archive not working i trying to install maven...
#  22582  imap4 error on lotus notes 90 recently i have installed lotus notes 9 on ubu...
#  22583  hiding partition in nautilius i using ubuntu 1310 and nautilus file v 382 on...
#  22584  show unity launcher on with key combination i wanted to ask if it is possibl...
#  22585  unknown filesystem error after virtualbox disk resize i was using ubuntu 120...
#  22586  what is the uuid of my swap drive i dualbooting ubuntu 1310 on an asus windo...
#  22587  is there any userfriendly nurbs modelling software i can t find nurbs softwa...
#  22588  aptana studio 3 does nt work after upgrade from ubuntu 1204 to 1404 when i u...
#  22589  what are the system requirements of ubuntu 1210 can i install ubuntu on my s...
#  22590  what is exactly juju i am a sysadmin and i heard about juju from canonical w...
#  22591  installing ubuntu with windows installer if i use this method to install ubu...
#  22592  measuring and documenting internet speed download and upload i looking for a...
#  22593  world of warcraft crashes when entering the game i installed wow and it star...
#  22594  ubuntu does not recognize my geforce 540m when i go into system info it says...
#  22595  remove back versions of ubuntu while installing the most recent version of t...
#  22596  skype crashes after installing ubuntu 1304 after upgrading from ubuntu 1210 ...
#
#                                                                               question2  \
#  0      fan noise of dell inspirion after ubuntu 1210 is installed alongside windows...
#  1      usb without a hard drive i running a dell latitude xt that the hardcover wen...
#  2      best way to backup a whole dualboot system i finally have my pc exactly the ...
#  3      how to configure mod_rewrite correctly while using cakephp this at first mig...
#  4      an upgrade from to is not supported with this tool i am trying to upgrade bu...
#  5      how do i read cpu temperatures on a phenom ii processor i am trying to measu...
#  6      how can i change the resolution seen by a bootloader in virtualbox i am usin...
#  7      how can i stop being prompted to unlock the keyring on boot found a solution...
#  8      system running in low graphics mode ubuntu 1204 when i boot my ubuntu 1204 i...
#  9      install ruby ubuntu with updatealternatives command i have 2 questions about...
#  10     upgrade wubi installed ubuntu 1204 lts to 1404 lts i installed ubuntu 1204 l...
#  11     install tomcat on ubuntu 1104 i tried installing tomcat on 1104 using but i ...
#  12     how can i write apps with java for ubuntu phone how can i write apps with ja...
#  13     unable to install anything from software center package issues in 1210 fresh...
#  14     ca nt use require all without order deny allow so i upgraded my ubuntu serve...
#  15     how to reset a vm to a previous snapshot i am running ubuntu virtual machine...
#  16     how to upgrade to the development version of ubuntu 1104 how do i upgrade ub...
#  17     software to _easily_ create hotspot at this link there is a tricky and not a...
#  18     system runs unusably slow everything was running fine until i installed a ch...
#  19     how can i run ubuntu via my vm i trying to install ubuntu 1204 to run in vir...
#  20     will installing ubuntu using wubi erase windows i have an hp laptop with 2 p...
#  21     how do install ubuntu tv on 1204 all the guides for installing ubuntu tv see...
#  22     copy from main system and paste in vbox how can i copy the information from ...
#  23     are existing updates available after end of support i am using ubuntu 1104 a...
#  24     1 or 2 partitions for 2 opsystems windows 7 ubuntu what is recommended insta...
#  25             how to compile source code from a tarball please explain in an easy way
#  26     web browser unable to open any pages while any other app is downloading at f...
#  27     how to change a dconf setting for customized live cd i am creating a live cd...
#  28     ubuntu 1204 lts no longer able to boot normally until recently i was able to...
#  29     i did somethings with mountmanager and i have some small problems i tried to...
#  ...                                                                                ...
#  22567  how do i find out which version and derivative of ubuntu is right for my har...
#  22568  boot problem after an update i ubuntu 1204 installed along with windows 7 af...
#  22569  mounting a drive using sshfs i am trying mount a remote drive using sshfs on...
#  22570  how to get a resource file from a project in the qt creator i have installed...
#  22571  appearance does not change on switching the theme if i select radiance or am...
#  22572  problem getting amd radeon 6870 configured i am trying to launch amd catalys...
#  22573  how do i remove a malformed line from my sourceslist i have unistalled and r...
#  22574  wireless related issues on hp machine there was an install fest recently in ...
#  22575  how do i install skype i want to install skype but i ca nt locate it in soft...
#  22576  who pays for ubuntu ubuntu seems expensive to develop and maintain bandwidth...
#  22577  problem installing vim i tried installing vim using terminal command but it ...
#  22578  ubuntu one api file upload maximum size i making an application using ubunuo...
#  22579  installing ubuntu on a preinstalled windows 8 64bit system uefi supported i ...
#  22580  can not install ubuntu 1104 apps on live usb i have ubuntu 1104 on a 36gb us...
#  22581  how can i get apt to use a mirror close to me or choose a faster mirror down...
#  22582  ubuntu 1404 optical output on ht omega claro halo sound card does nt work i ...
#  22583  suggestion for a light weight distro of linux iam a new ubuntu user i instal...
#  22584  how can i reverse natural scrolling on ubuntu 1310 i tried to change the fil...
#  22585  grub rescue error unknown filesystem i have a multiboot system set up the sy...
#  22586  how to configure isa proxy authentification i installed ubuntu 1304 my probl...
#  22587  can a deb package contain a ppa dependency and install packages from the ppa...
#  22588  translating inittab line to ubuntu 904 jaunty system equivalent i trying to ...
#  22589  what are the system requirements for each flavour of ubuntu desktop i thinki...
#  22590                    what is a juju charm what is a juju charm what is it used for
#  22591  can not update with aptget update or update manager beforehand excuse me i n...
#  22592  how to develop ubuntu apps 2013 edition i know this question has come up bef...
#  22593  there an issue with an alphabeta release of ubuntu what should i do i been r...
#  22594  how can i get my graphics card to be recognized in system info i am new to l...
#  22595  how do i remove or hide old kernel versions to clean up the boot menu every ...
#  22596  skype crashes with a segmentation fault under 1304 skype is crashing with a ...
#
#           qid
#  0      22575
#  1      20244
#  2      13802
#  3      17018
#  4      10400
#  5       1217
#  6       6008
#  7        105
#  8       1936
#  9       5120
#  10     19768
#  11      6610
#  12      9950
#  13      8804
#  14     12129
#  15     11048
#  16     10566
#  17     23144
#  18     17803
#  19      8280
#  20      2439
#  21     13024
#  22      6068
#  23      2330
#  24     10054
#  25     22980
#  26      1860
#  27     14624
#  28      2759
#  29     18267
#  ...      ...
#  22567   7812
#  22568   7160
#  22569   4396
#  22570  20180
#  22571   1420
#  22572   9463
#  22573   6209
#  22574  13338
#  22575  13069
#  22576    521
#  22577  19274
#  22578   1211
#  22579   4430
#  22580   2784
#  22581   2928
#  22582  11195
#  22583   6562
#  22584  18323
#  22585   2416
#  22586   7539
#  22587  12036
#  22588   4019
#  22589   8865
#  22590   9714
#  22591  19504
#  22592  14428
#  22593   7394
#  22594   4672
#  22595   3928
#  22596   8550
#
#  [22597 rows x 4 columns],        is_duplicate  \
#  0                 0
#  1                 0
#  2                 1
#  3                 0
#  4                 1
#  5                 0
#  6                 0
#  7                 0
#  8                 1
#  9                 1
#  10                0
#  11                1
#  12                1
#  13                1
#  14                0
#  15                0
#  16                1
#  17                0
#  18                0
#  19                1
#  20                1
#  21                1
#  22                1
#  23                1
#  24                1
#  25                0
#  26                0
#  27                0
#  28                0
#  29                0
#  ...             ...
#  37970             0
#  37971             1
#  37972             0
#  37973             0
#  37974             1
#  37975             1
#  37976             1
#  37977             0
#  37978             0
#  37979             1
#  37980             1
#  37981             1
#  37982             1
#  37983             0
#  37984             0
#  37985             1
#  37986             0
#  37987             0
#  37988             0
#  37989             0
#  37990             0
#  37991             1
#  37992             0
#  37993             0
#  37994             0
#  37995             0
#  37996             0
#  37997             1
#  37998             0
#  37999             0
#
#                                                                               question1  \
#  0      volume muted around 0 20 level it was fine until 1310 i tested with pavucont...
#  1      how to get a netgear n300 adapter to work with ubuntu 1210 32bit no other tu...
#  2      how to make a disk image and restore from it later i a new linux user i rein...
#  3      rfkill list all not showing anything on the prompt i have dual installed ubu...
#  4      an upgrade from to is not unsupported with this tool error while upgrading a...
#  5      localhost problem i just installed lamp recently to study wordpress i instal...
#  6      reverting after installing lubuntu desktop i have installed ubuntu 1204 lts ...
#  7      hdd makes highpitched noise in windows but it is silent in ubuntu i was just...
#  8      how to fix the system is running in lowgraphics mode error note this is an a...
#  9      no ruby alternatives on 1104 1110 running fails 2 days ago january 15th 2012...
#  10     windows 8 not booting from grub 2 i have done a fair amount of research and ...
#  11     how do i install apache tomcat 7 troubleshooting with apache tomcat 7 steps ...
#  12     will it be possible to create appsgames in java se or java me on new ubuntu ...
#  13     trouble downloading updates due to a hash sum mismatch error when i check fo...
#  14     is there a desktop application for launchpadnet i was looking at the launchp...
#  15     issue with cp command when i was copying in i am not able to copy file in wi...
#  16     how do i upgrade to the development release aka ubuntu1 how do i upgrade to ...
#  17     is there an equivalent of the filebrowser applet for unity i really really m...
#  18     how long can my data stay on ubuntu one how long can my data stay on ubuntu ...
#  19     can not install ubuntu in virtualbox due to this kernel requires an x8664 cp...
#  20     what the difference between wubi and a regular alongside windows installatio...
#  21     how do i install ubuntu tv on my computer i have a media pc connected to my ...
#  22     how to copy paste from ubuntu virtualbox guest to windows host i am running ...
#  23     how to install software or upgrade from old unsupported release recently i h...
#  24     what are the benefits of a disk install vs wubi and can i migrate my setting...
#  25     firefox 401 crash intermittently and log out intermittently firefox 401 is c...
#  26     debug overheating issue on sony vaio pro 13 intel haswell i am using my sony...
#  27     sshfs transform_symlinks is broken i been using the same fstab command for a...
#  28     how to get data from a bluetooth device that is not visible i just bought a ...
#  29     sudo aptget install nautilusopenterminal does not work i newly installed ubu...
#  ...                                                                                ...
#  37970  connectedness to ubuntu server run on ec2 i have a ubuntu ec2 with its defau...
#  37971  how to install oracle10g i want to set up oracle10g on my ubuntu 1110 waiter...
#  37972  how do i set up itunes on ubuntu i assay different shipway to set up itunes ...
#  37973  the design of updating after add a ppa repository when add a ppa depository ...
#  37974  how do i fix a problem with mergelist or position data file could not be par...
#  37975  how do i get my mac to boot from an ubuntu usb key if you pick out usb and m...
#  37976  how can you proctor cyberspace download exercise some broadband provider imp...
#  37977  how to make a systemwide environmental variable i privation to set an enviro...
#  37978  slow up bash tab pass completion my knock shell tab pass completion is very ...
#  37979  why do nt the ubuntu depository wealthy person the latest version of softwar...
#  37980  how do i instal ubuntu i would the like to see a full moon howto on how to s...
#  37981  how do i curtail usb admission i am the system decision maker on a web using...
#  37982  my computer boot to a blackness projection screen what option do i wealthy p...
#  37983  unable to login to steam steam is have problem link up to the server since s...
#  37984  unity not support on an hp pavillion g6 i set up ubuntu 1104 on my new hp pa...
#  37985  how do i stop gui i demand to move into the bid line alone with no gui to se...
#  37986  trade partition not acknowledge the disk drive with uuid is not ready yet or...
#  37987  rsync permission issue via ssh i am patronage up a network waiter via ssh un...
#  37988  virtualbox Department of Energy nt work with a real number divider so i foll...
#  37989   gui tool for Apache are there any gui tool for configure and monitoring Apache
#  37990  e unable to locate bundle bfgminer i recently set up cubieboard with linaro ...
#  37991  how do i free up disc infinite my ubuntu cloud waiter has left lonesome 900m...
#  37992  install will not go on ok so i am very much new to Linux and i rich person b...
#  37993  keyboard language ego electric switch i on 1310 i wealthy person an Italian ...
#  37994  connexion decline when i transfer information from dell laptop to lenovo lap...
#  37995  how can i fix my xvinfo how can i fix my x serverdriver additional info foll...
#  37996  list python category belongings i would the likes of to get list of python f...
#  37997  permission deny are you root i get this fault whenever i try to set up plan ...
#  37998  is it safe to instal the nvidiacurrent driver and then rich person this hdd ...
#  37999  victimization in mkdir i just deprivation to know how do i use with bid i wa...
#
#                                                                               question2  \
#  0      fan noise of dell inspirion after ubuntu 1210 is installed alongside windows...
#  1      usb without a hard drive i running a dell latitude xt that the hardcover wen...
#  2      best way to backup a whole dualboot system i finally have my pc exactly the ...
#  3      how to configure mod_rewrite correctly while using cakephp this at first mig...
#  4      an upgrade from to is not supported with this tool i am trying to upgrade bu...
#  5      how do i read cpu temperatures on a phenom ii processor i am trying to measu...
#  6      how can i change the resolution seen by a bootloader in virtualbox i am usin...
#  7      how can i stop being prompted to unlock the keyring on boot found a solution...
#  8      system running in low graphics mode ubuntu 1204 when i boot my ubuntu 1204 i...
#  9      install ruby ubuntu with updatealternatives command i have 2 questions about...
#  10     upgrade wubi installed ubuntu 1204 lts to 1404 lts i installed ubuntu 1204 l...
#  11     install tomcat on ubuntu 1104 i tried installing tomcat on 1104 using but i ...
#  12     how can i write apps with java for ubuntu phone how can i write apps with ja...
#  13     unable to install anything from software center package issues in 1210 fresh...
#  14     ca nt use require all without order deny allow so i upgraded my ubuntu serve...
#  15     how to reset a vm to a previous snapshot i am running ubuntu virtual machine...
#  16     how to upgrade to the development version of ubuntu 1104 how do i upgrade ub...
#  17     software to _easily_ create hotspot at this link there is a tricky and not a...
#  18     system runs unusably slow everything was running fine until i installed a ch...
#  19     how can i run ubuntu via my vm i trying to install ubuntu 1204 to run in vir...
#  20     will installing ubuntu using wubi erase windows i have an hp laptop with 2 p...
#  21     how do install ubuntu tv on 1204 all the guides for installing ubuntu tv see...
#  22     copy from main system and paste in vbox how can i copy the information from ...
#  23     are existing updates available after end of support i am using ubuntu 1104 a...
#  24     1 or 2 partitions for 2 opsystems windows 7 ubuntu what is recommended insta...
#  25             how to compile source code from a tarball please explain in an easy way
#  26     web browser unable to open any pages while any other app is downloading at f...
#  27     how to change a dconf setting for customized live cd i am creating a live cd...
#  28     ubuntu 1204 lts no longer able to boot normally until recently i was able to...
#  29     i did somethings with mountmanager and i have some small problems i tried to...
#  ...                                                                                ...
#  37970  minimum ubuntu 1204 for scheduling i new to Linux i Windows 7 put in side by...
#  37971  how to put in prophet 10g on ubuntu 1110 is it possible to put in prophet 10...
#  37972                                                      problem with libmysqlclient
#  37973  set up bid of depot Energy nt work i a new user of ubuntu Linux exploitation...
#  37974  hi i can not download anything from the software eye nor can i get my update...
#  37975  ubuntu usb on a mac i follow the instruction manual on ubuntucom to set up u...
#  37976  monitor net employment on ubuntu any thought how one would proctor internet ...
#  37977  can i psychiatrist gedit side panel my laptop computer projection screen is ...
#  37978  unable to clear php file on Linux platform on ubuntu i copy over my file ove...
#  37979  why is ubuntu redis packet so old the latest release is 267 248 is now view ...
#  37980  where can i download ubuntu for intel i ca nt discovery an ubuntu installer ...
#  37981  curb usb entree i victimization ubuntu as a waiter with Windows xp client i ...
#  37982  install nvidia driver got space silver screen i have got the job with updati...
#  37983  WiFi mathematical function key not workings on hp laptop i rich person an hp...
#  37984  is there any way i can get scrybe gesture workflow technology scrybe is a pr...
#  37985  disenable x server and gnome temporarily i demand to put to death some test ...
#  37986  i ca nt get my audio to work in ubuntu 1310 ca nt get verbalizer or earpiece...
#  37987  e package synaptic has no installation campaigner when seek to instal synapt...
#  37988  how do i preclude beingness kick back to the login silver screen every time ...
#  37989  package go miss after bootup and certain indicator do nt seem to set up anym...
#  37990  how do i setup freelan in ubuntu i can not discovery any tutorial on-line ta...
#  37991  remove fresh practical application i running play low on difficult thrust in...
#  37992  how to open share folder in Windows xp from nuclear-powered submarine i have...
#  37993  hdmi issue with macbook pro 81 on ubuntu 1404 i have a macbook pro mbp 81 os...
#  37994  why there is no loginpassword for ubuntu one nether system predilection what...
#  37995  how to put in mozilla central in Linux i rich person download the mozillacen...
#  37996  bluez 519 ps4 comptroller i presently wealthy person a problem when union my...
#  37997                           reckon installation what should i do to solve this job
#  37998  i ca nt clear up url in hotot when i chink on any nexus an mistake message p...
#  37999  update director can not update due to dpkg error ubuntu 1210 i just download...
#
#           qid
#  0      22575
#  1      20244
#  2      13802
#  3      17018
#  4      10400
#  5       1217
#  6       6008
#  7        105
#  8       1936
#  9       5120
#  10     19768
#  11      6610
#  12      9950
#  13      8804
#  14     12129
#  15     11048
#  16     10566
#  17     23144
#  18     17803
#  19      8280
#  20      2439
#  21     13024
#  22      6068
#  23      2330
#  24     10054
#  25     22980
#  26      1860
#  27     14624
#  28      2759
#  29     18267
#  ...      ...
#  37970   6134
#  37971   5179
#  37972   7395
#  37973  15736
#  37974  12512
#  37975  12199
#  37976   7824
#  37977   1219
#  37978   1135
#  37979  10943
#  37980   5794
#  37981  10799
#  37982   8469
#  37983  18433
#  37984  15392
#  37985   7661
#  37986   5999
#  37987   3700
#  37988   9619
#  37989  13469
#  37990    776
#  37991  12610
#  37992     95
#  37993  17624
#  37994    726
#  37995  11441
#  37996    597
#  37997   3051
#  37998    515
#  37999    712
#
#  [38000 rows x 4 columns])

# %%
preprocess(ask_15k)
features(ask_15k)
h = heuristic(ask_15k)
h.groupby('is_duplicate').count()
# Out:
# Preprocess done!
# Features done!
# 40
# 3535
# Heuristic done!
#               question1  question2     id
# is_duplicate
# 0                 11739      11739  11739
# 1                  6836       6836   6836

# %%
preprocess(ask_5k)
features(ask_5k)
test1 = reverse_order(ask_5k)

preprocess(ask_10k)
features(ask_10k)
test2 = heuristic(ask_10k)

preprocess(ask_15k)
features(ask_15k)
test3 = heuristic(ask_15k)
# Out:
# Preprocess done!
# Features done!
# Reverse done!
# Preprocess done!
# /Users/andrada/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3778: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# Features done!
# Heuristic done!
# Preprocess done!
# Features done!
# Heuristic done!

# %%
print(test1.count()[0])
print(test2.count()[0])
print(test3.count()[0])
# Out:
# 6782
# 13569
# 18575

# %%
def percentage(x,y):
    print(round((y*100)/x,2))

# %%
percentage(20912, 4541)
percentage(30387, 8010)
percentage(37589, 11367)
percentage(42539, 13709)
np.mean([21.71, 26.36, 30.24, 32.23])
# Out:
# 21.71
# 26.36
# 30.24
# 32.23
# 27.634999999999998

# %%
percentage(20912, 5074)
percentage(30387, 9082)
percentage(37589, 12730)
percentage(42539, 15322)
np.mean([24.26, 29.89, 33.87, 36.02])
# Out:
# 24.26
# 29.89
# 33.87
# 36.02
# 31.010000000000005

# %%
percentage(5000, 2295)
percentage(10000, 3622)
percentage(15000, 6066)
np.mean([45.9, 36.22, 40.44])
# Out:
# 45.9
# 36.22
# 40.44
# 40.85333333333333

# %%
print("Number of duplicates {}%".format(round(df_5k[df_5k.columns[0]].mean()*100, 2)))
# Out:
# Number of duplicates 37.84%

# %%
print("Number of duplicates {}%".format(round(df_10k[df_10k.columns[0]].mean()*100, 2)))
# Out:
# Number of duplicates 36.29%

# %%
print("Number of duplicates {}%".format(round(df_15k[df_15k.columns[0]].mean()*100, 2)))
# Out:
# Number of duplicates 36.09%

# %%
print(df_5k['word_overlap_score'].mean())
test1['q1_lemma'] = test1['question1'].apply(lemmatize_text)
test1['q2_lemma'] = test1['question2'].apply(lemmatize_text)
test1['word_overlap_score'] = test1.apply(word_match_share, axis=1, raw=True)
print(test1['word_overlap_score'].mean())

print(df_10k['word_overlap_score'].mean())
test2['q1_lemma'] = test2['question1'].apply(lemmatize_text)
test2['q2_lemma'] = test2['question2'].apply(lemmatize_text)
test2['word_overlap_score'] = test2.apply(word_match_share, axis=1, raw=True)
print(test2['word_overlap_score'].mean())

print(df_15k['word_overlap_score'].mean())
test3['q1_lemma'] = test3['question1'].apply(lemmatize_text)
test3['q2_lemma'] = test3['question2'].apply(lemmatize_text)
test3['word_overlap_score'] = test3.apply(word_match_share, axis=1, raw=True)
print(test3['word_overlap_score'].mean())
# Out:
# 0.45284124103218676
# 0.49022946651117455
# 0.4520219727890094
# 0.5154047055249136
# 0.45360792319090837
# 0.5027675857457312

# %%
augment_data(ask_5k, '5')
augment_data(ask_10k, '10')
augment_data(ask_15k, '15')
# Out:
# Preprocess done!
# Features done!
# /Users/andrada/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:23: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# Heuristic done!
# /Users/andrada/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3778: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# Synonyms done!
# Reverse done!
# aici
# Preprocess done!
# Features done!
# Heuristic done!
# Synonyms done!
# Reverse done!
# aici
# Preprocess done!
# Features done!
# Heuristic done!
# Synonyms done!
# Reverse done!
# aici
# (       is_duplicate  \
#  0                 1
#  1                 1
#  2                 1
#  3                 1
#  4                 1
#  5                 0
#  6                 0
#  7                 0
#  8                 0
#  9                 0
#  10                0
#  11                1
#  12                0
#  13                1
#  14                1
#  15                1
#  16                0
#  17                0
#  18                0
#  19                0
#  20                1
#  21                0
#  22                1
#  23                0
#  24                0
#  25                1
#  26                0
#  27                1
#  28                0
#  29                1
#  ...             ...
#  29970             0
#  29971             0
#  29972             0
#  29973             0
#  29974             1
#  29975             0
#  29976             0
#  29977             0
#  29978             0
#  29979             0
#  29980             0
#  29981             1
#  29982             0
#  29983             0
#  29984             1
#  29985             0
#  29986             0
#  29987             0
#  29988             1
#  29989             0
#  29990             0
#  29991             1
#  29992             1
#  29993             0
#  29994             0
#  29995             1
#  29996             1
#  29997             1
#  29998             0
#  29999             0
#
#                                                                               question1  \
#  0      how do i upgrade to a newer version of ubuntu what are the different ways i ...
#  1      how to avoid duplicate entries in the same command is listed in my history a...
#  2      tips to extend battery life for laptops and notebooks this question is prese...
#  3      how do i install ubuntu i would like to see a full howto on how to install u...
#  4      long wait time on login when i log in on my server i get this then i must wa...
#  5      show macchanger info in conky is there a way to show macchanger info in conk...
#  6      how to hide file extensions is there a way to hide all file extensions like ...
#  7      gnome3 extension collapse how to solve it or make gnome3 to default i tried ...
#  8      mounting cifs network shares when logging into user account i have a couple ...
#  9      ubuntu 1204 runs in 2d only has intel 82865g graphics ubuntu 1204 runs only ...
#  10     repositories added for maya not precise i wanted to test cinnamon in my xubu...
#  11     how can i use the windows super key the windows key seems to not have any us...
#  12     should i install zip or use gzip i have downloaded some files i wish to deco...
#  13     how do i install a or file i have downloaded targz files but i do nt know ho...
#  14     how do i improve boot speed i have seen many videos that make ubuntu faster ...
#  15     how do i fix this e type is not known on line in source list update error ev...
#  16     grub and tty display incorrectly on ubuntu 1204 i am using ubuntu 1204 x64 d...
#  17     messed up with mount and naming a partition delete a folder in file system i...
#  18     file does nt exist when trying to change permissions following the avasys im...
#  19     how do i install libimobiledevice i have precise and i want to get my iphone...
#  20     make firefox only use gtk theme on browser chrome but ignore on websites i h...
#  21     ca nt execute files in windows partitions from ubuntu i am using ubuntu 1404...
#  22     no wireless in ubuntu 1310 when i upgraded to ubuntu 1310 i ca nt connect to...
#  23     lenovo g5030 not having any hardware switch for wifi or bluetooth after inst...
#  24     headphones do nt work on dell studio xps 16 with ubuntu 1210 i am running ub...
#  25     my computer boots to a black screen what options do i have to fix it i am tr...
#  26     ubuntu how to listen to music streams on the web without flash by finding th...
#  27     computer boots directly to windows after installing ubuntu i bought vaio e14...
#  28     vm dont uses graphicscard i wand to play a linux game 64bit version of kerba...
#  29     radeon hd 2000 3000 4000 on ubuntu 12042 and higher fglrx legacy unsupported...
#  ...                                                                                ...
#  29970  operation not permitted when logged in using admini i installed ubuntu 1310 ...
#  29971  putting internal hard drive in another pc if i install ubuntu on my current ...
#  29972  how do i reinstall package mount when trying to update use software center i...
#  29973  synaptic package manager problem i am trying to install ubiquityfrontendgtk ...
#  29974  upgrading to 1210 i have 1010 running on my hp compaq i would like to upgrad...
#  29975  is there an easily searchable database of hardware that works with ubuntu i ...
#  29976  problem with sharing wireless internet connection over adhoc on ubuntu 1404 ...
#  29977  eating all the cpu i have ubuntu 1210 system and it works slow for checking ...
#  29978  baremetal mode for ubuntu i interested to benchmark a consolemode applicatio...
#  29979  nautilus search options show only the file type filter i ubuntu 1304 32 bit ...
#  29980  when i boot i have to log in 3 to 5 times there is always 2 email logins i h...
#  29981  how to fix dependencies broken packages i new to ubuntu i like to use it but...
#  29982  my windows 7 is getting the an error occurred press controlaltdel message on...
#  29983  why does kmail make jpg files larger when i forward them when i forward emai...
#  29984  duplicated menu panel indicators and taskbar ubuntu 1204 the first time i lo...
#  29985  my software center asks me to repair but says it cant repair due to an error...
#  29986  can i backup my windows partition with acronis and then reinstall it inside ...
#  29987  installing ftp and adding user to ftp account i installed ftp on a ubuntu se...
#  29988  is it possible to minimize by mouse click is it possible to minimize or clos...
#  29989  unable to root login and may be problem initially i am trying to connect wit...
#  29990  how to extract xubuntu live dvd styles icons fonts and install them on an ex...
#  29991  how to disable notifications i am using ubuntu 1204 with gnomefallbacksessio...
#  29992  how to make appendable cd i want to make a appendable cd so that i can write...
#  29993  choose gcc and g version so i have installed gcc44 and gcc43 same for g now ...
#  29994  ca nt login in to ubuntu vm whenever i try to login into my ubuntu vm from m...
#  29995  dependency problems now not able to install or remove any package i was inst...
#  29996  which ubuntu version to use on a maxdata laptop eco 3100x with this system i...
#  29997  wubildrmbr missing or corrupt i dual booting w7 and ubuntu installed from wu...
#  29998  how to load a apllication to the memory using shell scripting how to load a ...
#  29999  getting commandnotfound working under zsh i trying to get the feature under ...
#
#                                                                               question2  \
#  0      is a 1004 lts to 1204 release upgrade possible i have a beloved high perform...
#  1      no duplicated lines in bash history supposedly adding export to would do the...
#  2      how can i save my laptops battery from draining i am using ubuntu 1204 switc...
#  3      how do i install ubuntu using a cd i have recently burned ubuntu to a cd usi...
#  4      how to speed up ssh login using a public key and putty i am using putty to l...
#  5      qualcomm atheros ar9485 wireless network adapter not working on ubuntu 1310 ...
#  6      i want to associate a file type to an installed program deluge but it does n...
#  7      hibernate option missing in ubuntu 1204 after extending the root partition t...
#  8      randomly getting logged out it just started today i getting repeatedly logge...
#  9      how to get ubuntu vb guest to use monitor native resolution i am running an ...
#  10     xubuntu 1404 install fails on dell inspiron b130 with broadcom 4318 i have a...
#  11     what is win key used for in linux hello i have a windows pc but i installed ...
#  12     sudo hangs without prompting for password i just did a fresh install of ubun...
#  13     how to install firefox 1401 from a tarbz2 which is located in i have downloa...
#  14     start up on ubuntu 1210 is much slower than on 1204 start up toward login sc...
#  15     update manager is not working properly i get this message after trying the u...
#  16     how can i get vlc to automatically play dvds when inserted running 1304 i tr...
#  17     how does canonical report and transfer software center sales money to app de...
#  18     why does cpu usage remain at 100 after running mathematica 9 i have installe...
#  19     dns server help with redirect traffic of a specific url to a local ip addres...
#  20     changing the color of the google search bar in the webpage how can i change ...
#  21     corrupted hard drive how can i rescue my files lets get things straight i a ...
#  22     no wireless in ubuntu 1310 maybe need wireless driver hi after updating to u...
#  23     juju and openstack provisioning i new to juju and openstack and currently de...
#  24     how to install cedarview driver in kubuntu 1204 lts i am running kubuntu 120...
#  25     blank screen on server install with a ssd i trying to install ubuntu server ...
#  26     which application do you recommend for watching tv dvb at the moment i use m...
#  27     ubuntu is nt on boot i have windows 7 on my notebook and i installed ubuntu ...
#  28     how do i set up pulseaudio to work in multiseat how do i set up pulseaudio f...
#  29     problems with amd graphics driver installation on ubuntu 1204 i installed ub...
#  ...                                                                                ...
#  29970  disagreement between about this computer and i have a dell xps that had ubun...
#  29971  a strange issue with open programs recently my speakers stopped working i wa...
#  29972  software center opens and closes ubuntu 1304 software center opens and then ...
#  29973  viewing windows files i have dual boot ubuntu 1010 and windows 7 how would i...
#  29974  how to install software or upgrade from old unsupported release recently i h...
#  29975  just installed ubuntu no proprietary drivers i just installed ubuntu but it ...
#  29976  ubuntu keeps randomly switching disks it took me a while to notice but here ...
#  29977  any way to stop the launcher from appearing when clickdragging a file so whe...
#  29978  error calling startservicebyname for orggtkvfsdaemon timeout was reached gio...
#  29979  password is incorrect when tried to login into ubuntu 1304 i recently instal...
#  29980  gedit from terminal inconsistent behaviour i tend to frequently open a text ...
#  29981  installing skype on ubuntu 1304 64bit here is what i tried i also tried all ...
#  29982  how do i reload images in an email if i accidentally click show remote conte...
#  29983  computer starts ubuntu asks username and password and then freezes i just in...
#  29984  gnomepanel has multiple rows how to undo that on ubuntu 1204 i use openbox w...
#  29985  grub install to wrong partition has broken windows startup when i installed ...
#  29986  wubi admin permission in graphic environment and installing question while i...
#  29987  nvidia optimus work with ubuntu 134 and nvidia optimus work with ubuntu 134 ...
#  29988  can i use the unity launcher icon to minimize applicationswindows i do nt kn...
#  29989  how to play two sounds the idea the internet radio plays constantly in some ...
#  29990  xerox work center jcl syntax error printing error 016749 its long since xero...
#  29991  how to clear ubuntu notifications is there a way to clear the pop up notific...
#  29992  why is it not possible to burn a multisession dvd using brasero the multises...
#  29993  why ca nt be opened preventing a kernel upgrade i try to update my ubuntu 12...
#  29994  internet passthrough to android phone is there any way to use the internet p...
#  29995  how do i resolve unmet dependencies how do i resolve unmet package dependenc...
#  29996  ubuntu on 256mb ram i was wondering if i can use ubuntu scale down version o...
#  29997  wubildrmbr missing or corrupt i dual booting w7 and ubuntu installed from wu...
#  29998  how do i create system settings entries i like to start learning how to deve...
#  29999  installing ubuntu on my tablet i have a bsnl penta tablet with me i want to ...
#
#            id
#  0       2620
#  1       5015
#  2       4357
#  3       8220
#  4       9382
#  5      12085
#  6      13276
#  7      16920
#  8      14553
#  9      12637
#  10     20515
#  11      6412
#  12     16334
#  13      1677
#  14      8745
#  15      1061
#  16     22769
#  17     16352
#  18     17816
#  19     21149
#  20      7252
#  21      1206
#  22     11487
#  23      6964
#  24     12850
#  25     10019
#  26     20253
#  27      3529
#  28     18849
#  29       595
#  ...      ...
#  29970  11811
#  29971    676
#  29972  22135
#  29973   9540
#  29974   9163
#  29975  17746
#  29976  15535
#  29977   6224
#  29978  16588
#  29979  21329
#  29980   2097
#  29981   6808
#  29982  11210
#  29983   5875
#  29984  13858
#  29985   8542
#  29986  16717
#  29987   3814
#  29988   1553
#  29989   3777
#  29990  18111
#  29991   5462
#  29992   5993
#  29993  20109
#  29994  14994
#  29995  12771
#  29996   9623
#  29997   5448
#  29998  11729
#  29999  23392
#
#  [30000 rows x 4 columns],        is_duplicate  \
#  0                 1
#  1                 1
#  2                 1
#  3                 1
#  4                 1
#  5                 0
#  6                 0
#  7                 0
#  8                 0
#  9                 0
#  10                0
#  11                1
#  12                0
#  13                1
#  14                1
#  15                1
#  16                0
#  17                0
#  18                0
#  19                0
#  20                1
#  21                0
#  22                1
#  23                0
#  24                0
#  25                1
#  26                0
#  27                1
#  28                0
#  29                1
#  ...             ...
#  18545             0
#  18546             0
#  18547             0
#  18548             0
#  18549             1
#  18550             0
#  18551             0
#  18552             1
#  18553             0
#  18554             1
#  18555             0
#  18556             1
#  18557             1
#  18558             0
#  18559             1
#  18560             0
#  18561             0
#  18562             0
#  18563             1
#  18564             1
#  18565             0
#  18566             1
#  18567             0
#  18568             1
#  18569             0
#  18570             1
#  18571             1
#  18572             0
#  18573             0
#  18574             0
#
#                                                                               question1  \
#  0      how do i upgrade to a newer version of ubuntu what are the different ways i ...
#  1      how to avoid duplicate entries in the same command is listed in my history a...
#  2      tips to extend battery life for laptops and notebooks this question is prese...
#  3      how do i install ubuntu i would like to see a full howto on how to install u...
#  4      long wait time on login when i log in on my server i get this then i must wa...
#  5      show macchanger info in conky is there a way to show macchanger info in conk...
#  6      how to hide file extensions is there a way to hide all file extensions like ...
#  7      gnome3 extension collapse how to solve it or make gnome3 to default i tried ...
#  8      mounting cifs network shares when logging into user account i have a couple ...
#  9      ubuntu 1204 runs in 2d only has intel 82865g graphics ubuntu 1204 runs only ...
#  10     repositories added for maya not precise i wanted to test cinnamon in my xubu...
#  11     how can i use the windows super key the windows key seems to not have any us...
#  12     should i install zip or use gzip i have downloaded some files i wish to deco...
#  13     how do i install a or file i have downloaded targz files but i do nt know ho...
#  14     how do i improve boot speed i have seen many videos that make ubuntu faster ...
#  15     how do i fix this e type is not known on line in source list update error ev...
#  16     grub and tty display incorrectly on ubuntu 1204 i am using ubuntu 1204 x64 d...
#  17     messed up with mount and naming a partition delete a folder in file system i...
#  18     file does nt exist when trying to change permissions following the avasys im...
#  19     how do i install libimobiledevice i have precise and i want to get my iphone...
#  20     make firefox only use gtk theme on browser chrome but ignore on websites i h...
#  21     ca nt execute files in windows partitions from ubuntu i am using ubuntu 1404...
#  22     no wireless in ubuntu 1310 when i upgraded to ubuntu 1310 i ca nt connect to...
#  23     lenovo g5030 not having any hardware switch for wifi or bluetooth after inst...
#  24     headphones do nt work on dell studio xps 16 with ubuntu 1210 i am running ub...
#  25     my computer boots to a black screen what options do i have to fix it i am tr...
#  26     ubuntu how to listen to music streams on the web without flash by finding th...
#  27     computer boots directly to windows after installing ubuntu i bought vaio e14...
#  28     vm dont uses graphicscard i wand to play a linux game 64bit version of kerba...
#  29     radeon hd 2000 3000 4000 on ubuntu 12042 and higher fglrx legacy unsupported...
#  ...                                                                                ...
#  18545  playing a midi keyboard without jack how to use jack and pulseaudioalsa so i...
#  18546  how to install librsvg2 how do you install with the command i tried the foll...
#  18547  does ubuntu support for my laptop am using lenovo thinkpad edge laptop model...
#  18548  uvc webcam upside down with google gtalk plugin i got google talk plugin ins...
#  18549  can i upgrade from 1210 to 1304 without losing my data and if so how the onl...
#  18550  access to different directories i have recently moved to ubuntu 1204 and not...
#  18551  how get bansheeextensionalbumartwriter working in a previous question here t...
#  18552  how to remove youtube application from launcher the first time i visited you...
#  18553  list all human users how can i list all human users that i created i tried a...
#  18554  update manager generates 404 error while attempting update will not update w...
#  18555  how would one change the gdm theme in ubuntu 1204 i am using gdm not lightdm...
#  18556  enable desktop wallpaper change with elapsed time is there a way to randomis...
#  18557  why do i need a strong password for my ubuntu user account assuming that no ...
#  18558  how to switch to a commandline console in order to run the commands in low g...
#  18559  ubuntu windows and dos in a laptop i have purchased a lenovo thinkpad laptop...
#  18560  upgrade manager can not find a server my upgrade manager went zombie a long ...
#  18561  problem mounting drive i asked this question earlier i opted for mearging th...
#  18562  can i skip over releases when upgrading i am currently using ubuntu 1004 i k...
#  18563  why do my avi files display with funky colors when i capture hd video with a...
#  18564  can i change the launcher location i want to know if is possible because i w...
#  18565  after upgrading to 1204 the scanner from brother printer mfc290c does not wo...
#  18566  making customized distro of ubuntu server minimal i made an ubuntu installat...
#  18567  unable to add cisco vpn connection i am setting up cisco vpn on ubuntu 1204 ...
#  18568  running java applets in the browser with my 1204 if i point my browser eithe...
#  18569  when buying a computer for ubuntu what should i look for i am buying a compu...
#  18570  mac address changing in ubuntu 1204 i am trying to change the mac address of...
#  18571  installation process takes too long when i was installing ubuntu 1204 lts in...
#  18572  i ca nt access any webpage on my chromium browser using proxy connection i a...
#  18573  can i install an older version of ubuntu over a new one i installed ubuntu 1...
#  18574  how to know the source of ubuntu 64 or 32 bit i have an ubuntu source on a f...
#
#                                                                               question2  \
#  0      is a 1004 lts to 1204 release upgrade possible i have a beloved high perform...
#  1      no duplicated lines in bash history supposedly adding export to would do the...
#  2      how can i save my laptops battery from draining i am using ubuntu 1204 switc...
#  3      how do i install ubuntu using a cd i have recently burned ubuntu to a cd usi...
#  4      how to speed up ssh login using a public key and putty i am using putty to l...
#  5      qualcomm atheros ar9485 wireless network adapter not working on ubuntu 1310 ...
#  6      i want to associate a file type to an installed program deluge but it does n...
#  7      hibernate option missing in ubuntu 1204 after extending the root partition t...
#  8      randomly getting logged out it just started today i getting repeatedly logge...
#  9      how to get ubuntu vb guest to use monitor native resolution i am running an ...
#  10     xubuntu 1404 install fails on dell inspiron b130 with broadcom 4318 i have a...
#  11     what is win key used for in linux hello i have a windows pc but i installed ...
#  12     sudo hangs without prompting for password i just did a fresh install of ubun...
#  13     how to install firefox 1401 from a tarbz2 which is located in i have downloa...
#  14     start up on ubuntu 1210 is much slower than on 1204 start up toward login sc...
#  15     update manager is not working properly i get this message after trying the u...
#  16     how can i get vlc to automatically play dvds when inserted running 1304 i tr...
#  17     how does canonical report and transfer software center sales money to app de...
#  18     why does cpu usage remain at 100 after running mathematica 9 i have installe...
#  19     dns server help with redirect traffic of a specific url to a local ip addres...
#  20     changing the color of the google search bar in the webpage how can i change ...
#  21     corrupted hard drive how can i rescue my files lets get things straight i a ...
#  22     no wireless in ubuntu 1310 maybe need wireless driver hi after updating to u...
#  23     juju and openstack provisioning i new to juju and openstack and currently de...
#  24     how to install cedarview driver in kubuntu 1204 lts i am running kubuntu 120...
#  25     blank screen on server install with a ssd i trying to install ubuntu server ...
#  26     which application do you recommend for watching tv dvb at the moment i use m...
#  27     ubuntu is nt on boot i have windows 7 on my notebook and i installed ubuntu ...
#  28     how do i set up pulseaudio to work in multiseat how do i set up pulseaudio f...
#  29     problems with amd graphics driver installation on ubuntu 1204 i installed ub...
#  ...                                                                                ...
#  18545  login dialog and all windows flickering background displaying fine on an ati...
#  18546  dependency which is missing however package not broken the context i wanted ...
#  18547  software center subscription is for quantal even though i on precise i notic...
#  18548  why does my ethernet port sometimes not work i noticed that my ethernet port...
#  18549  how do i upgrade to the development release aka ubuntu1 how do i upgrade to ...
#  18550  where does ubuntu one store my information i would like to get 20gb on ubunt...
#  18551  trendnet tew624ub 300mbps correct optimized driver got a trendnet tew624ub 3...
#  18552  how do i remove youtube sidebar integration i accidentally agreed to allow f...
#  18553  distribution upgrade froze my system just tried to upgrade to 1104 with upda...
#  18554  how can i fix a 404 error when updating packages ppa seems to be constantly ...
#  18555  error ca nt change mac interface up or not permission invalid argument so i ...
#  18556  how do i create a desktop wallpaper slideshow how do i create a desktop wall...
#  18557  any reason to have a strong user password i recently decided to change my ve...
#  18558  uninstall problem in wine program i have installed adobe illustrator 8 in my...
#  18559  how do i restore grub after i ran a fixmbr command i have deleted a partitio...
#  18560  will ubuntu do any damage to my files installed on windows i have one drive ...
#  18561  how to delete nomodeset from my grub file in order to boot normally how can ...
#  18562  installing java in ubuntu this is my first time using linux ubuntu i trying ...
#  18563  ubuntu and vlc make default and hue i have recently installed vlc i have fou...
#  18564  can i move the unity launcher i can t get used to the new unity system i d l...
#  18565  how to change autodim time i running unity on 1204 precise lets me control w...
#  18566    how do i make my own customized ubuntu version is there any gui tool for that
#  18567  minimum and maximum cpu frequency are equal i just noticed my laptop stared ...
#  18568  how do i install java how do i install java and also in my browser so websit...
#  18569  set target disk and reboot remotely i want to be able to set my target disk ...
#  18570  how do i change spoof my mac address and easily switch between multiple ones...
#  18571  why are updates downloading so slow all other connection speeds are normal a...
#  18572  how to access a guest os running in virtual box from a different user accoun...
#  18573  no application menus in awesome yesterday i installed awesome via an excelle...
#  18574  drm r600_uvd_init uvd not responding trying to reset the vcpu i am using ubu...
#
#            id
#  0       2620
#  1       5015
#  2       4357
#  3       8220
#  4       9382
#  5      12085
#  6      13276
#  7      16920
#  8      14553
#  9      12637
#  10     20515
#  11      6412
#  12     16334
#  13      1677
#  14      8745
#  15      1061
#  16     22769
#  17     16352
#  18     17816
#  19     21149
#  20      7252
#  21      1206
#  22     11487
#  23      6964
#  24     12850
#  25     10019
#  26     20253
#  27      3529
#  28     18849
#  29       595
#  ...      ...
#  18545  20519
#  18546  15250
#  18547  16946
#  18548  22438
#  18549   7988
#  18550  15591
#  18551  11289
#  18552  11974
#  18553  20214
#  18554   4461
#  18555  12332
#  18556  10110
#  18557   4975
#  18558  17792
#  18559   4999
#  18560   8329
#  18561    930
#  18562  21498
#  18563  10990
#  18564   5170
#  18565  16930
#  18566   6334
#  18567  10002
#  18568  11673
#  18569   9112
#  18570   9103
#  18571   2515
#  18572  16363
#  18573  14611
#  18574   6388
#
#  [18575 rows x 4 columns],        is_duplicate  \
#  0                 1
#  1                 1
#  2                 1
#  3                 1
#  4                 1
#  5                 0
#  6                 0
#  7                 0
#  8                 0
#  9                 0
#  10                0
#  11                1
#  12                0
#  13                1
#  14                1
#  15                1
#  16                0
#  17                0
#  18                0
#  19                0
#  20                1
#  21                0
#  22                1
#  23                0
#  24                0
#  25                1
#  26                0
#  27                1
#  28                0
#  29                1
#  ...             ...
#  29970             0
#  29971             0
#  29972             0
#  29973             0
#  29974             1
#  29975             0
#  29976             0
#  29977             0
#  29978             0
#  29979             0
#  29980             0
#  29981             1
#  29982             0
#  29983             0
#  29984             1
#  29985             0
#  29986             0
#  29987             0
#  29988             1
#  29989             0
#  29990             0
#  29991             1
#  29992             1
#  29993             0
#  29994             0
#  29995             1
#  29996             1
#  29997             1
#  29998             0
#  29999             0
#
#                                                                               question1  \
#  0      how do i upgrade to a newer version of ubuntu what are the different ways i ...
#  1      how to avoid duplicate entries in the same command is listed in my history a...
#  2      tips to extend battery life for laptops and notebooks this question is prese...
#  3      how do i install ubuntu i would like to see a full howto on how to install u...
#  4      long wait time on login when i log in on my server i get this then i must wa...
#  5      show macchanger info in conky is there a way to show macchanger info in conk...
#  6      how to hide file extensions is there a way to hide all file extensions like ...
#  7      gnome3 extension collapse how to solve it or make gnome3 to default i tried ...
#  8      mounting cifs network shares when logging into user account i have a couple ...
#  9      ubuntu 1204 runs in 2d only has intel 82865g graphics ubuntu 1204 runs only ...
#  10     repositories added for maya not precise i wanted to test cinnamon in my xubu...
#  11     how can i use the windows super key the windows key seems to not have any us...
#  12     should i install zip or use gzip i have downloaded some files i wish to deco...
#  13     how do i install a or file i have downloaded targz files but i do nt know ho...
#  14     how do i improve boot speed i have seen many videos that make ubuntu faster ...
#  15     how do i fix this e type is not known on line in source list update error ev...
#  16     grub and tty display incorrectly on ubuntu 1204 i am using ubuntu 1204 x64 d...
#  17     messed up with mount and naming a partition delete a folder in file system i...
#  18     file does nt exist when trying to change permissions following the avasys im...
#  19     how do i install libimobiledevice i have precise and i want to get my iphone...
#  20     make firefox only use gtk theme on browser chrome but ignore on websites i h...
#  21     ca nt execute files in windows partitions from ubuntu i am using ubuntu 1404...
#  22     no wireless in ubuntu 1310 when i upgraded to ubuntu 1310 i ca nt connect to...
#  23     lenovo g5030 not having any hardware switch for wifi or bluetooth after inst...
#  24     headphones do nt work on dell studio xps 16 with ubuntu 1210 i am running ub...
#  25     my computer boots to a black screen what options do i have to fix it i am tr...
#  26     ubuntu how to listen to music streams on the web without flash by finding th...
#  27     computer boots directly to windows after installing ubuntu i bought vaio e14...
#  28     vm dont uses graphicscard i wand to play a linux game 64bit version of kerba...
#  29     radeon hd 2000 3000 4000 on ubuntu 12042 and higher fglrx legacy unsupported...
#  ...                                                                                ...
#  29970  dissonance betwixt astir this data processor and i have a dingle xps that ha...
#  29971  a strange issue with clear plan late my utterer stop workings i was able to ...
#  29972  software package heart clear and conclusion ubuntu 1304 software system midd...
#  29973  screening Windows file i wealthy person double boot ubuntu 1010 and Windows ...
#  29974  how to set up software or raise from old unsupported release latterly i weal...
#  29975  just instal ubuntu no proprietary driver i just install ubuntu but it is not...
#  29976  ubuntu support arbitrarily switching saucer it take me a piece to notice but...
#  29977  any way to halt the launcher from appearing when clickdragging a data file s...
#  29978  mistake vocation startservicebyname for orggtkvfsdaemon timeout was attain g...
#  29979  word is incorrect when seek to login into ubuntu 1304 i lately set up ubuntu...
#  29980  gedit from terminus inconsistent behavior i incline to frequently clear a te...
#  29981  instalment skype on ubuntu 1304 64bit here is what i seek i besides assay al...
#  29982  how do i recharge image in an e-mail if i accidentally chink show remote con...
#  29983  information processing system start ubuntu inquire username and watchword an...
#  29984  gnomepanel has multiple row how to undo that on ubuntu 1204 i use openbox wi...
#  29985  chow set up to wrongfulness partition has interrupt Windows startup when i p...
#  29986  wubi admin permission in graphic environment and installment interrogation w...
#  29987  nvidia optimus work with ubuntu 134 and nvidia optimus work with ubuntu 134 ...
#  29988  can i use the wholeness launcher icon to minimise applicationswindows i do n...
#  29989  how to drama two sound the idea the net radio play constantly in some condit...
#  29990  xerox copy work eye jcl phrase structure mistake printing fault 016749 its l...
#  29991  how to clear ubuntu notification is there a way to clear the pop up presentm...
#  29992  why is it not possible to burning a multisession dvd exploitation brasero th...
#  29993  why ca nt be open prevent a kernel acclivity i try to update my ubuntu 1204 ...
#  29994  internet passthrough to humanoid phone is there any way to use the cyberspac...
#  29995  how do i resolution unmet dependency how do i firmness unmet parcel dependen...
#  29996  ubuntu on 256mb ram i was inquire if i can use ubuntu ordered series down fe...
#  29997  wubildrmbr miss or demoralize i double boot w7 and ubuntu set up from wubi i...
#  29998  how do i create system scene entry i the likes of to start learning how to d...
#  29999  installation ubuntu on my tablet i wealthy person a bsnl penta tablet with m...
#
#                                                                               question2  \
#  0      is a 1004 lts to 1204 release upgrade possible i have a beloved high perform...
#  1      no duplicated lines in bash history supposedly adding export to would do the...
#  2      how can i save my laptops battery from draining i am using ubuntu 1204 switc...
#  3      how do i install ubuntu using a cd i have recently burned ubuntu to a cd usi...
#  4      how to speed up ssh login using a public key and putty i am using putty to l...
#  5      qualcomm atheros ar9485 wireless network adapter not working on ubuntu 1310 ...
#  6      i want to associate a file type to an installed program deluge but it does n...
#  7      hibernate option missing in ubuntu 1204 after extending the root partition t...
#  8      randomly getting logged out it just started today i getting repeatedly logge...
#  9      how to get ubuntu vb guest to use monitor native resolution i am running an ...
#  10     xubuntu 1404 install fails on dell inspiron b130 with broadcom 4318 i have a...
#  11     what is win key used for in linux hello i have a windows pc but i installed ...
#  12     sudo hangs without prompting for password i just did a fresh install of ubun...
#  13     how to install firefox 1401 from a tarbz2 which is located in i have downloa...
#  14     start up on ubuntu 1210 is much slower than on 1204 start up toward login sc...
#  15     update manager is not working properly i get this message after trying the u...
#  16     how can i get vlc to automatically play dvds when inserted running 1304 i tr...
#  17     how does canonical report and transfer software center sales money to app de...
#  18     why does cpu usage remain at 100 after running mathematica 9 i have installe...
#  19     dns server help with redirect traffic of a specific url to a local ip addres...
#  20     changing the color of the google search bar in the webpage how can i change ...
#  21     corrupted hard drive how can i rescue my files lets get things straight i a ...
#  22     no wireless in ubuntu 1310 maybe need wireless driver hi after updating to u...
#  23     juju and openstack provisioning i new to juju and openstack and currently de...
#  24     how to install cedarview driver in kubuntu 1204 lts i am running kubuntu 120...
#  25     blank screen on server install with a ssd i trying to install ubuntu server ...
#  26     which application do you recommend for watching tv dvb at the moment i use m...
#  27     ubuntu is nt on boot i have windows 7 on my notebook and i installed ubuntu ...
#  28     how do i set up pulseaudio to work in multiseat how do i set up pulseaudio f...
#  29     problems with amd graphics driver installation on ubuntu 1204 i installed ub...
#  ...                                                                                ...
#  29970  operation not permit when log in exploitation admini i set up ubuntu 1310 lo...
#  29971  putt internal hard driving force in some other pc if i set up ubuntu on my e...
#  29972  how do i reinstall package riding horse when assay to update use computer so...
#  29973  synaptic package director problem i am attempt to instal ubiquityfrontendgtk...
#  29974  upgrade to 1210 i have 1010 running game on my hp compaq i would the like to...
#  29975  is there an easily searchable database of hardware that works with ubuntu i ...
#  29976  problem with sharing wireless net connexion over adhoc on ubuntu 1404 i new ...
#  29977  feeding all the cpu i rich person ubuntu 1210 system and it plant slow up fo...
#  29978  baremetal manner for ubuntu i interest to benchmark a consolemode practical ...
#  29979  nuclear submarine hunting option show solitary the data file type filter i u...
#  29980  when i boot i have to log in 3 to 5 times there is always 2 email logins i h...
#  29981  how to fix dependency interrupt bundle i new to ubuntu i the likes of to use...
#  29982  my Windows 7 is acquiring the an fault fall out pressure controlaltdel messa...
#  29983  why Energy Department kmail make jpg file bigger when i forward them when i ...
#  29984  repeat card panel indicator and taskbar ubuntu 1204 the first time i log int...
#  29985  my software package center ask me to fix but say it buzzword repair due to a...
#  29986  can i backup my Windows divider with acronis and then reinstall it interior ...
#  29987  installment ftp and add user to ftp history i set up ftp on a ubuntu server ...
#  29988  is it possible to minimize by mouse chink is it possible to minimise or fini...
#  29989  unable to root login and may be job initially i am try to tie with github wi...
#  29990  how to extract xubuntu populate dvd mode icon fount and put in them on an be...
#  29991  how to disable notification i am victimization ubuntu 1204 with gnomefallbac...
#  29992  how to make appendable cd i deprivation to brand a appendable cd so that i c...
#  29993  select gcc and g version so i rich person put in gcc44 and gcc43 Lapplander ...
#  29994  ca nt login in to ubuntu vm whenever i try to login into my ubuntu vm from m...
#  29995  dependency problem now not able to install or remove any packet i was instal...
#  29996  which ubuntu version to use on a maxdata laptop eco 3100x with this system i...
#  29997  wubildrmbr miss or demoralize i dual boot w7 and ubuntu put in from wubi i h...
#  29998  how to burden a apllication to the memory victimization shell script how to ...
#  29999  acquiring commandnotfound working nether zsh i essay to get the characterist...
#
#            id
#  0       2620
#  1       5015
#  2       4357
#  3       8220
#  4       9382
#  5      12085
#  6      13276
#  7      16920
#  8      14553
#  9      12637
#  10     20515
#  11      6412
#  12     16334
#  13      1677
#  14      8745
#  15      1061
#  16     22769
#  17     16352
#  18     17816
#  19     21149
#  20      7252
#  21      1206
#  22     11487
#  23      6964
#  24     12850
#  25     10019
#  26     20253
#  27      3529
#  28     18849
#  29       595
#  ...      ...
#  29970  11811
#  29971    676
#  29972  22135
#  29973   9540
#  29974   9163
#  29975  17746
#  29976  15535
#  29977   6224
#  29978  16588
#  29979  21329
#  29980   2097
#  29981   6808
#  29982  11210
#  29983   5875
#  29984  13858
#  29985   8542
#  29986  16717
#  29987   3814
#  29988   1553
#  29989   3777
#  29990  18111
#  29991   5462
#  29992   5993
#  29993  20109
#  29994  14994
#  29995  12771
#  29996   9623
#  29997   5448
#  29998  11729
#  29999  23392
#
#  [30000 rows x 4 columns])

# %%
df_10k["question1"] = df_10k['question1'].str.replace('[^\w\s]','')
df_10k["question2"] = df_10k['question2'].str.replace('[^\w\s]','')

df_50k["question1"] = df_50k['question1'].str.replace('[^\w\s]','')
df_50k["question2"] = df_50k['question2'].str.replace('[^\w\s]','')


# df1['question1'] = df1['question1'].apply(lambda x: [item for item in x if item not in stop])
# df1['question2'] = df1['question2'].apply(lambda x: [item for item in x if item not in stop])

# df2['question1'] = df2['question1'].apply(lambda x: [item for item in x if item not in stop])
# df2['question2'] = df2['question2'].apply(lambda x: [item for item in x if item not in stop])

qs10k = df1['question1'].str.lower().tolist() + df1['question2'].str.lower().tolist()
qs50k = df2['question1'].str.lower().tolist() + df2['question2'].str.lower().tolist()

# %%
df_50k[df_50k['question1'] == df_50k['question2']]
# Out:
#        is_duplicate  \
# 974               1
# 3267              1
# 4905              1
# 6057              1
# 9785              1
# 10320             0
# 10521             1
# 10892             1
# 11082             1
# 11782             1
# 14638             1
# 15323             1
# 16093             1
# 17309             1
# 18661             1
# 19878             1
# 21379             1
# 22521             1
# 26832             1
# 29137             1
# 29933             0
# 30792             1
# 35846             1
# 35872             1
# 40762             1
# 43948             1
# 44249             1
# 49766             1
#
#                                                          question1  \
# 974                           How do they measure mean sea level ?
# 3267                    Why are n't most Chinese good at English ?
# 4905      What are some of the most lucrative insurances to sell ?
# 6057   How do programming contest problem setters make test cas...
# 9785                   Why ca n't matter be created or destroyed ?
# 10320                                                Who is this ?
# 10521                         What 's your favorite Chinese food ?
# 10892                    What are the benefits of reading novels ?
# 11082                Why did Bhishma alienate Karna from the War ?
# 11782               How do small business owners use CRM systems ?
# 14638             What is the one thing you do n't regret buying ?
# 15323  I have completed AutoCAD and SolidWorks . Please give me...
# 16093                          How do I get internship at Google ?
# 17309  What are the biggest misconceptions that Indians have ab...
# 18661  What jobs can a PhD in Electrical Engineering get beside...
# 19878          What is Hillary Clinton 's plan to deal with ISIS ?
# 21379            What is the best free / cheap CRM for a startup ?
# 22521     What significance does the Passion of Jesus have today ?
# 26832  Is there an air cooler with humidity control available i...
# 29137                        Why should n't I visit your country ?
# 29933                                            Does he like me ?
# 30792                   What do you usually do with the internet ?
# 35846     What are some of the Great facts about Maharana Pratap ?
# 35872  Shall I consider studying MBBS in Ukraine if I do n't ge...
# 40762  What is the net worth of famous comedian Sapan Verma , i...
# 43948  I want to export my products worldwide , is there any si...
# 44249                         What is Rob Halford 's vocal range ?
# 49766         Can I enter Hong Kong or Macau with a Chinese visa ?
#
#                                                          question2      id  \
# 974                           How do they measure mean sea level ?  259230
# 3267                    Why are n't most Chinese good at English ?  356338
# 4905      What are some of the most lucrative insurances to sell ?  323638
# 6057   How do programming contest problem setters make test cas...  237589
# 9785                   Why ca n't matter be created or destroyed ?   12675
# 10320                                                Who is this ?  299692
# 10521                         What 's your favorite Chinese food ?  163465
# 10892                    What are the benefits of reading novels ?   87351
# 11082                Why did Bhishma alienate Karna from the War ?  254786
# 11782               How do small business owners use CRM systems ?  257139
# 14638             What is the one thing you do n't regret buying ?  390001
# 15323  I have completed AutoCAD and SolidWorks . Please give me...   57769
# 16093                          How do I get internship at Google ?  237131
# 17309  What are the biggest misconceptions that Indians have ab...  199461
# 18661  What jobs can a PhD in Electrical Engineering get beside...  186992
# 19878          What is Hillary Clinton 's plan to deal with ISIS ?  380702
# 21379            What is the best free / cheap CRM for a startup ?  310342
# 22521     What significance does the Passion of Jesus have today ?  189442
# 26832  Is there an air cooler with humidity control available i...  385298
# 29137                        Why should n't I visit your country ?  403758
# 29933                                            Does he like me ?  220551
# 30792                   What do you usually do with the internet ?   50696
# 35846     What are some of the Great facts about Maharana Pratap ?  113858
# 35872  Shall I consider studying MBBS in Ukraine if I do n't ge...  152445
# 40762  What is the net worth of famous comedian Sapan Verma , i...  283725
# 43948  I want to export my products worldwide , is there any si...   40775
# 44249                         What is Rob Halford 's vocal range ?  365042
# 49766         Can I enter Hong Kong or Macau with a Chinese visa ?  291676
#
#                                                           q1_lemma  \
# 974                  [How, do, they, measure, mean, sea, level, ?]
# 3267          [Why, are, n't, most, Chinese, good, at, English, ?]
# 4905   [What, are, some, of, the, most, lucrative, insurance, t...
# 6057   [How, do, programming, contest, problem, setter, make, t...
# 9785         [Why, ca, n't, matter, be, created, or, destroyed, ?]
# 10320                                           [Who, is, this, ?]
# 10521                 [What, 's, your, favorite, Chinese, food, ?]
# 10892             [What, are, the, benefit, of, reading, novel, ?]
# 11082      [Why, did, Bhishma, alienate, Karna, from, the, War, ?]
# 11782       [How, do, small, business, owner, use, CRM, system, ?]
# 14638  [What, is, the, one, thing, you, do, n't, regret, buying...
# 15323  [I, have, completed, AutoCAD, and, SolidWorks, ., Please...
# 16093                 [How, do, I, get, internship, at, Google, ?]
# 17309  [What, are, the, biggest, misconception, that, Indians, ...
# 18661  [What, job, can, a, PhD, in, Electrical, Engineering, ge...
# 19878  [What, is, Hillary, Clinton, 's, plan, to, deal, with, I...
# 21379  [What, is, the, best, free, /, cheap, CRM, for, a, start...
# 22521  [What, significance, doe, the, Passion, of, Jesus, have,...
# 26832  [Is, there, an, air, cooler, with, humidity, control, av...
# 29137               [Why, should, n't, I, visit, your, country, ?]
# 29933                                      [Does, he, like, me, ?]
# 30792         [What, do, you, usually, do, with, the, internet, ?]
# 35846  [What, are, some, of, the, Great, fact, about, Maharana,...
# 35872  [Shall, I, consider, studying, MBBS, in, Ukraine, if, I,...
# 40762  [What, is, the, net, worth, of, famous, comedian, Sapan,...
# 43948  [I, want, to, export, my, product, worldwide, ,, is, the...
# 44249                [What, is, Rob, Halford, 's, vocal, range, ?]
# 49766  [Can, I, enter, Hong, Kong, or, Macau, with, a, Chinese,...
#
#                                                           q2_lemma  \
# 974                  [How, do, they, measure, mean, sea, level, ?]
# 3267          [Why, are, n't, most, Chinese, good, at, English, ?]
# 4905   [What, are, some, of, the, most, lucrative, insurance, t...
# 6057   [How, do, programming, contest, problem, setter, make, t...
# 9785         [Why, ca, n't, matter, be, created, or, destroyed, ?]
# 10320                                           [Who, is, this, ?]
# 10521                 [What, 's, your, favorite, Chinese, food, ?]
# 10892             [What, are, the, benefit, of, reading, novel, ?]
# 11082      [Why, did, Bhishma, alienate, Karna, from, the, War, ?]
# 11782       [How, do, small, business, owner, use, CRM, system, ?]
# 14638  [What, is, the, one, thing, you, do, n't, regret, buying...
# 15323  [I, have, completed, AutoCAD, and, SolidWorks, ., Please...
# 16093                 [How, do, I, get, internship, at, Google, ?]
# 17309  [What, are, the, biggest, misconception, that, Indians, ...
# 18661  [What, job, can, a, PhD, in, Electrical, Engineering, ge...
# 19878  [What, is, Hillary, Clinton, 's, plan, to, deal, with, I...
# 21379  [What, is, the, best, free, /, cheap, CRM, for, a, start...
# 22521  [What, significance, doe, the, Passion, of, Jesus, have,...
# 26832  [Is, there, an, air, cooler, with, humidity, control, av...
# 29137               [Why, should, n't, I, visit, your, country, ?]
# 29933                                      [Does, he, like, me, ?]
# 30792         [What, do, you, usually, do, with, the, internet, ?]
# 35846  [What, are, some, of, the, Great, fact, about, Maharana,...
# 35872  [Shall, I, consider, studying, MBBS, in, Ukraine, if, I,...
# 40762  [What, is, the, net, worth, of, famous, comedian, Sapan,...
# 43948  [I, want, to, export, my, product, worldwide, ,, is, the...
# 44249                [What, is, Rob, Halford, 's, vocal, range, ?]
# 49766  [Can, I, enter, Hong, Kong, or, Macau, with, a, Chinese,...
#
#        word_overlap  word_overlap_score  q1_n_words  q2_n_words  \
# 974               8                 1.0           8           8
# 3267              9                 1.0           9           9
# 4905             11                 1.0          11          11
# 6057             10                 1.0          10          10
# 9785              9                 1.0           9           9
# 10320             4                 1.0           4           4
# 10521             7                 1.0           7           7
# 10892             8                 1.0           8           8
# 11082             9                 1.0           9           9
# 11782             9                 1.0           9           9
# 14638            11                 1.0          11          11
# 15323            17                 1.0          17          17
# 16093             8                 1.0           8           8
# 17309            11                 1.0          11          11
# 18661            16                 1.0          20          20
# 19878            11                 1.0          11          11
# 21379            12                 1.0          12          12
# 22521            10                 1.0          10          10
# 26832            12                 1.0          12          12
# 29137             8                 1.0           8           8
# 29933             5                 1.0           5           5
# 30792             8                 1.0           9           9
# 35846            11                 1.0          11          11
# 35872            14                 1.0          15          15
# 40762            14                 1.0          14          14
# 43948            16                 1.0          19          19
# 44249             8                 1.0           8           8
# 49766            12                 1.0          12          12
#
#                                                         q1_synonym  \
# 974                       How do they step mean value sea degree ?
# 3267           Why are n't most Chinese good at English language ?
# 4905     What are some of the most moneymaking insurance to sell ?
# 6057   How do programming contest problem setter brand tryout e...
# 9785                       Why ca n't thing be create or destroy ?
# 10320                                                Who is this ?
# 10521                        What 's your favourite Chinese food ?
# 10892                      What are the benefit of reading novel ?
# 11082                Why did Bhishma alienate Karna from the War ?
# 11782         How do small business concern owner use CRM system ?
# 14638         What is the one thing you do n't regret purchasing ?
# 15323  I rich person complete AutoCAD and SolidWorks . please g...
# 16093                          How do I get internship at Google ?
# 17309  What are the large misconception that Indian have astir ...
# 18661  What line of work can a PhD in electrical engineering ge...
# 19878  What is Sir Edmund Hillary Hilary Clinton 's programme t...
# 21379            What is the best free / cheap CRM for a startup ?
# 22521  What significance DOE the passionateness of Deliverer ri...
# 26832  Is there an air ice chest with humidity control availabl...
# 29137                          Why should n't I visit your state ?
# 29933                                      Energy he the like me ?
# 30792                  What do you normally do with the internet ?
# 35846      What are some of the great fact about Maharana Pratap ?
# 35872  Shall I see poring over MBBS in Ukraine if I do n't get ...
# 40762  What is the net worth of famous comic Sapan Verma , in r...
# 43948  I want to exportation my ware worldwide , is there any l...
# 44249                       What is Rob Halford 's vocal compass ?
# 49766     Can I move into Hong Kong or Macau with a Chinese visa ?
#
#                                                         q2_synonym
# 974                    How do they measure mean value sea degree ?
# 3267                    Why are n't most Chinese good at English ?
# 4905       What are some of the most lucrative insurance to sell ?
# 6057   How do programing contest problem compositor brand trial...
# 9785                      Why ca n't thing be create or destruct ?
# 10320                                                Who is this ?
# 10521                         What 's your favorite Chinese food ?
# 10892                      What are the benefit of reading novel ?
# 11082                Why did Bhishma alienate Karna from the War ?
# 11782             How do small concern proprietor use CRM system ?
# 14638         What is the one thing you do n't sorrow purchasing ?
# 15323  I rich person complete AutoCAD and SolidWorks . delight ...
# 16093                          How do I get internship at Google ?
# 17309  What are the large misconception that American Indian ri...
# 18661  What line can a PhD in electrical engineering get in any...
# 19878  What is Hillary Clinton 's programme to business deal wi...
# 21379     What is the best free people / cheap CRM for a startup ?
# 22521  What significance Energy Department the passion of Chris...
# 26832  Is there an air cooler with humidness control available ...
# 29137                    Why should n't I visit your res publica ?
# 29933                                          Energy he like me ?
# 30792                     What do you ordinarily do with the net ?
# 35846      What are some of the great fact astir Maharana Pratap ?
# 35872  Shall I see perusal MBBS in Ukraine if I do n't get thro...
# 40762  What is the net worth of famous comic Sapan Verma , in r...
# 43948  I privation to export my merchandise world-wide , is the...
# 44249                         What is Rob Halford 's vocal reach ?
# 49766        Can I get in Hong Kong or Macau with a Chinese visa ?

# %%
Counter(" ".join(qs10k).split()).most_common(10)
# Out:
# [('the', 9353),
#  ('what', 7915),
#  ('is', 6617),
#  ('how', 5407),
#  ('i', 5385),
#  ('a', 5209),
#  ('to', 5119),
#  ('in', 4912),
#  ('do', 4110),
#  ('of', 3965)]

# %%
df_10k['q1_lemma'] = df_10k['question1'].apply(lemmatize_text)
df_10k['q2_lemma'] = df_10k['question2'].apply(lemmatize_text)
df_10k['word_overlap'] = df_10k.apply( word_match, axis=1, raw=True)
df_10k['word_overlap_score'] = df_10k.apply(word_match_share, axis=1, raw=True)
df_10k['q1_n_words'] = df_10k['question1'].apply(lambda row: len(row.split(" ")))
df_10k['q2_n_words'] = df_10k['question2'].apply(lambda row: len(row.split(" ")))

df_50k['q1_lemma'] = df_50k['question1'].apply(lemmatize_text)
df_50k['q2_lemma'] = df_50k['question2'].apply(lemmatize_text)
df_50k['word_overlap'] = df_50k.apply( word_match, axis=1, raw=True)
df_50k['word_overlap_score'] = df_50k.apply(word_match_share, axis=1, raw=True)
df_50k['q1_n_words'] = df_50k['question1'].apply(lambda row: len(row.split(" ")))
df_50k['q2_n_words'] = df_50k['question2'].apply(lambda row: len(row.split(" ")))

# %%
df_10k.head()
# Out:
#    is_duplicate                                          question1  \
# 0             0  Should Mandarin course be introduced in the sc...
# 1             0  How many people could become millionaires this...
# 2             0  What are good gifts for a foreign visitor to b...
# 3             1                How do you properly tie ice skates
# 4             1           Getting Started on Quora  What is Quora
#
#                                            question2      id  \
# 0  How do I get a Digital marketingSales job in H...   45324
# 1  Starting with nothing at all  how many years d...  263521
# 2  What are good gifts for a foreign visitor to b...  246571
# 3     How can I tie my ice skate shoelaces properly   313078
# 4                             Who and what is Quora   239251
#
#                                             q1_lemma  \
# 0  [Should, Mandarin, course, be, introduced, in,...
# 1  [How, many, people, could, become, millionaire...
# 2  [What, are, good, gift, for, a, foreign, visit...
# 3          [How, do, you, properly, tie, ice, skate]
# 4     [Getting, Started, on, Quora, What, is, Quora]
#
#                                             q2_lemma  word_overlap  \
# 0  [How, do, I, get, a, Digital, marketingSales, ...             5
# 1  [Starting, with, nothing, at, all, how, many, ...             3
# 2  [What, are, good, gift, for, a, foreign, visit...            21
# 3  [How, can, I, tie, my, ice, skate, shoelace, p...             3
# 4                        [Who, and, what, is, Quora]             3
#
#    word_overlap_score  q1_n_words  q2_n_words
# 0            0.192308          25          33
# 1            0.230769          16          17
# 2            0.954545          25          25
# 3            0.375000           8          10
# 4            0.500000           9           6

# %%
score_dup = df_10k[(df_10k['word_overlap_score'] > 0.5) & (df_10k['is_duplicate'] == 0)].count()[0]
score_nondup = df_10k[(df_10k['word_overlap_score'] < 0.5) & (df_10k['is_duplicate'] == 1)].count()[0]
print(score_dup)
print(score_nondup)
# Out:
# 1272
# 752

# %%
df_10k[(df_10k['word_overlap_score'] < 0.3) & (df_10k['is_duplicate'] == 1)]
# Out:
#       is_duplicate  \
# 380              1
# 701              1
# 1562             1
# 1697             1
# 1930             1
# 1978             1
# 2075             1
# 2280             1
# 2368             1
# 2595             1
# 2670             1
# 2726             1
# 2737             1
# 2769             1
# 3149             1
# 3486             1
# 3969             1
# 4135             1
# 4603             1
# 4730             1
# 4817             1
# 5271             1
# 5459             1
# 5647             1
# 5799             1
# 5860             1
# 6123             1
# 6360             1
# 6447             1
# 7280             1
# 7403             1
# 7438             1
# 7575             1
# 8458             1
# 8585             1
# 8693             1
# 8856             1
# 8965             1
# 9746             1
# 9949             1
#
#                                                                             question1  \
# 380                       Is there any evidence that can prove the existence of God ?
# 701                         What is the best way to increase traffic for a new blog ?
# 1562                                            What is the best way to learn chess ?
# 1697                                           Why do I get hiccups when I eat rice ?
# 1930                                               How can you cope with loneliness ?
# 1978                                      What works to make a man 's penis thicker ?
# 2075                                               How do I get rid of my belly fat ?
# 2280        Why Do You Think World War 3 Will Happen ? I Personally think it wo n't .
# 2368                             Who is currently winning the presidential election ?
# 2595                                                Did Mahabharata happen for real ?
# 2670         `` What does Donald Trump mean when he says '' `` I am Batman '' '' ? ''
# 2726                                                      Is there any hack for coc ?
# 2737                                              What are some examples of adverbs ?
# 2769                                 What would be required for Gary Johnson to win ?
# 3149                                             How does Sonakshi Sinha get movies ?
# 3486                                             How does one become rich real fast ?
# 3969                                 Is time travel possible through cosmic strings ?
# 4135  I am a mechanical engineer with no knowledge of programming . What is the be...
# 4603                                                  What existed before existence ?
# 4730                                                          How do I overcome OCD ?
# 4817                                                             How can I get MDMA ?
# 5271                            In what medium does light -LRB- photon -RRB- travel ?
# 5459             How do I download hotstar videos using Personal Computer or Laptop ?
# 5647  `` Is it possible that Donald Trump is campaigning very badly '' `` intentio...
# 5799    What are some good books or references to get started with machine learning ?
# 5860                           What are some times Gandalf as been completely wrong ?
# 6123  What are the best indoor exercises to remove belly fat completely and lose w...
# 6360                                            What 's the best way to become rich ?
# 6447                                                    Does Quora censor questions ?
# 7280  `` Why is it that the '' `` details '' '' box on Quora has such little room ...
# 7403                                        How do you train/improve your intuition ?
# 7438         How do I hack a WhatsApp account without having access to victim phone ?
# 7575      What is the best way or resources to learn english like a native speakers ?
# 8458                                   How can I get into a vlsi start up companies ?
# 8585                         Is it true goats will eat anything ? How do they do it ?
# 8693                                                  How can I lose my weight fast ?
# 8856                      How many heterosexual women have slept with another woman ?
# 8965                What would be impact on India if Donald Trump becomes President ?
# 9746                                     Why does n't Tesla use LIDAR in their cars ?
# 9949                                                     Why do central banks exist ?
#
#                                                                             question2  \
# 380    Do you believe in a god ? If so , what sort of testable evidence do you have ?
# 701                                            How do I increase traffic on my site ?
# 1562                                                            How do I play chess ?
# 1697         What causes hiccups after you eat and how can you rid yourself of them ?
# 1930                                            What are the ways to end loneliness ?
# 1978                                Can you make your penis larger at the age of 27 ?
# 2075                               What is the best way to reduce belly and arm fat ?
# 2280                                     What could potentially spark World War III ?
# 2368  All biases aside , at this point in time , who do you think will win the pre...
# 2595  Is Mahabharata real ? If it is , where are the present generations of Pandav...
# 2670                                                How is Donald Trump like Batman ?
# 2726                                             How can I hack clash of Clans game ?
# 2737                                            How do you teach kids about adverbs ?
# 2769           How could Gary Johnson end up winning the 2016 Presidential Election ?
# 3149  Why is Sonakshi Sinha -LRB- not a good actor , not very good looking and fat...
# 3486                         Rich people of Quora , what should I do to become rich ?
# 3969       Could time travel be a real thing ? Could it be scientifically explained ?
# 4135                                                How can I learn advanced Python ?
# 4603                          `` What was there before the '' `` beginning '' '' ? ''
# 4730                                          What is the best way to cope with OCD ?
# 4817                                                What are some ways to take MDMA ?
# 5271       `` If light is a wave , what is the medium that is '' `` waving '' '' ? ''
# 5459                                   Is there any way to download hotstar serials ?
# 5647          Is Hillary Clinton secretly paying Donald Trump to throw the election ?
# 5799                                How should I go about learning Machine Learning ?
# 5860  In The Hobbit and Lord of the Rings , when was Gandalf proven to be factuall...
# 6123                                        How can I lose belly fat if I 'm skinny ?
# 6360                                                                  Can I be rich ?
# 6447                                       Why does Quora have no freedom of speech ?
# 7280                      Why does Quora have a character limit in Question Details ?
# 7403                                       What are some ways to increase intuition ?
# 7438  My WhatsApp has been hacked by someone . How can she or he do it without get...
# 7575                                                 How can I learn English well ？ ?
# 8458  What are the required courses in the field of VLSI that students must take t...
# 8585                        What is the reason why goats are able to eat everything ?
# 8693         Whats the most effective way / solution to lose weight in a short time ?
# 8856  `` How many heterosexual women have '' `` dipped in the lady pond '' '' once...
# 8965  If Donald Trump wins the presidential election , how will the relationship b...
# 9746  Does the lack of lidar put Tesla at a disadvantage vs. other vehicle manufac...
# 9949  What is the concept behind formation of Central Banks all across the world ?...
#
#           id  \
# 380   392179
# 701    58143
# 1562  312035
# 1697  289881
# 1930   39598
# 1978   95639
# 2075   25022
# 2280  217632
# 2368  131951
# 2595   12525
# 2670   89957
# 2726  173058
# 2737  390282
# 2769   52940
# 3149  114245
# 3486   62725
# 3969  260381
# 4135  371455
# 4603  237425
# 4730   58917
# 4817  331959
# 5271  170341
# 5459   55275
# 5647  315276
# 5799   28694
# 5860   12934
# 6123  149707
# 6360  341804
# 6447  210811
# 7280  197271
# 7403   88177
# 7438  179109
# 7575  212888
# 8458  307420
# 8585   21062
# 8693   46914
# 8856  236886
# 8965  243167
# 9746  160093
# 9949  168666
#
#                                                                              q1_lemma  \
# 380          [Is, there, any, evidence, that, can, prove, the, existence, of, God, ?]
# 701           [What, is, the, best, way, to, increase, traffic, for, a, new, blog, ?]
# 1562                                  [What, is, the, best, way, to, learn, chess, ?]
# 1697                                 [Why, do, I, get, hiccup, when, I, eat, rice, ?]
# 1930                                       [How, can, you, cope, with, loneliness, ?]
# 1978                            [What, work, to, make, a, man, 's, penis, thicker, ?]
# 2075                                    [How, do, I, get, rid, of, my, belly, fat, ?]
# 2280  [Why, Do, You, Think, World, War, 3, Will, Happen, ?, I, Personally, think, ...
# 2368                    [Who, is, currently, winning, the, presidential, election, ?]
# 2595                                         [Did, Mahabharata, happen, for, real, ?]
# 2670  [``, What, doe, Donald, Trump, mean, when, he, say, '', ``, I, am, Batman, '...
# 2726                                              [Is, there, any, hack, for, coc, ?]
# 2737                                        [What, are, some, example, of, adverb, ?]
# 2769                      [What, would, be, required, for, Gary, Johnson, to, win, ?]
# 3149                                       [How, doe, Sonakshi, Sinha, get, movie, ?]
# 3486                                     [How, doe, one, become, rich, real, fast, ?]
# 3969                         [Is, time, travel, possible, through, cosmic, string, ?]
# 4135  [I, am, a, mechanical, engineer, with, no, knowledge, of, programming, ., Wh...
# 4603                                            [What, existed, before, existence, ?]
# 4730                                                   [How, do, I, overcome, OCD, ?]
# 4817                                                      [How, can, I, get, MDMA, ?]
# 5271                  [In, what, medium, doe, light, -LRB-, photon, -RRB-, travel, ?]
# 5459  [How, do, I, download, hotstar, video, using, Personal, Computer, or, Laptop...
# 5647  [``, Is, it, possible, that, Donald, Trump, is, campaigning, very, badly, ''...
# 5799  [What, are, some, good, book, or, reference, to, get, started, with, machine...
# 5860                  [What, are, some, time, Gandalf, a, been, completely, wrong, ?]
# 6123  [What, are, the, best, indoor, exercise, to, remove, belly, fat, completely,...
# 6360                                  [What, 's, the, best, way, to, become, rich, ?]
# 6447                                               [Does, Quora, censor, question, ?]
# 7280  [``, Why, is, it, that, the, '', ``, detail, '', '', box, on, Quora, ha, suc...
# 7403                                [How, do, you, train/improve, your, intuition, ?]
# 7438  [How, do, I, hack, a, WhatsApp, account, without, having, access, to, victim...
# 7575  [What, is, the, best, way, or, resource, to, learn, english, like, a, native...
# 8458                         [How, can, I, get, into, a, vlsi, start, up, company, ?]
# 8585           [Is, it, true, goat, will, eat, anything, ?, How, do, they, do, it, ?]
# 8693                                         [How, can, I, lose, my, weight, fast, ?]
# 8856           [How, many, heterosexual, woman, have, slept, with, another, woman, ?]
# 8965   [What, would, be, impact, on, India, if, Donald, Trump, becomes, President, ?]
# 9746                            [Why, doe, n't, Tesla, use, LIDAR, in, their, car, ?]
# 9949                                               [Why, do, central, bank, exist, ?]
#
#                                                                              q2_lemma  \
# 380   [Do, you, believe, in, a, god, ?, If, so, ,, what, sort, of, testable, evide...
# 701                                  [How, do, I, increase, traffic, on, my, site, ?]
# 1562                                                     [How, do, I, play, chess, ?]
# 1697  [What, cause, hiccup, after, you, eat, and, how, can, you, rid, yourself, of...
# 1930                                    [What, are, the, way, to, end, loneliness, ?]
# 1978                   [Can, you, make, your, penis, larger, at, the, age, of, 27, ?]
# 2075                  [What, is, the, best, way, to, reduce, belly, and, arm, fat, ?]
# 2280                            [What, could, potentially, spark, World, War, III, ?]
# 2368  [All, bias, aside, ,, at, this, point, in, time, ,, who, do, you, think, wil...
# 2595  [Is, Mahabharata, real, ?, If, it, is, ,, where, are, the, present, generati...
# 2670                                        [How, is, Donald, Trump, like, Batman, ?]
# 2726                                   [How, can, I, hack, clash, of, Clans, game, ?]
# 2737                                     [How, do, you, teach, kid, about, adverb, ?]
# 2769  [How, could, Gary, Johnson, end, up, winning, the, 2016, Presidential, Elect...
# 3149  [Why, is, Sonakshi, Sinha, -LRB-, not, a, good, actor, ,, not, very, good, l...
# 3486           [Rich, people, of, Quora, ,, what, should, I, do, to, become, rich, ?]
# 3969  [Could, time, travel, be, a, real, thing, ?, Could, it, be, scientifically, ...
# 4135                                        [How, can, I, learn, advanced, Python, ?]
# 4603             [``, What, wa, there, before, the, '', ``, beginning, '', '', ?, '']
# 4730                               [What, is, the, best, way, to, cope, with, OCD, ?]
# 4817                                        [What, are, some, way, to, take, MDMA, ?]
# 5271  [``, If, light, is, a, wave, ,, what, is, the, medium, that, is, '', ``, wav...
# 5459                          [Is, there, any, way, to, download, hotstar, serial, ?]
# 5647  [Is, Hillary, Clinton, secretly, paying, Donald, Trump, to, throw, the, elec...
# 5799                      [How, should, I, go, about, learning, Machine, Learning, ?]
# 5860  [In, The, Hobbit, and, Lord, of, the, Rings, ,, when, wa, Gandalf, proven, t...
# 6123                            [How, can, I, lose, belly, fat, if, I, 'm, skinny, ?]
# 6360                                                            [Can, I, be, rich, ?]
# 6447                              [Why, doe, Quora, have, no, freedom, of, speech, ?]
# 7280           [Why, doe, Quora, have, a, character, limit, in, Question, Details, ?]
# 7403                               [What, are, some, way, to, increase, intuition, ?]
# 7438  [My, WhatsApp, ha, been, hacked, by, someone, ., How, can, she, or, he, do, ...
# 7575                                        [How, can, I, learn, English, well, ？, ?]
# 8458  [What, are, the, required, course, in, the, field, of, VLSI, that, student, ...
# 8585            [What, is, the, reason, why, goat, are, able, to, eat, everything, ?]
# 8693  [Whats, the, most, effective, way, /, solution, to, lose, weight, in, a, sho...
# 8856  [``, How, many, heterosexual, woman, have, '', ``, dipped, in, the, lady, po...
# 8965  [If, Donald, Trump, win, the, presidential, election, ,, how, will, the, rel...
# 9746  [Does, the, lack, of, lidar, put, Tesla, at, a, disadvantage, vs., other, ve...
# 9949  [What, is, the, concept, behind, formation, of, Central, Banks, all, across,...
#
#       word_overlap  word_overlap_score  q1_n_words  q2_n_words  \
# 380              4            0.266667          12          19
# 701              3            0.272727          13           9
# 1562             2            0.266667           9           6
# 1697             3            0.260870          10          15
# 1930             2            0.266667           7           8
# 1978             3            0.272727          10          12
# 2075             3            0.272727          10          12
# 2280             2            0.166667          17           8
# 2368             4            0.296296           8          20
# 2595             3            0.240000           6          19
# 2670             3            0.260870          18           7
# 2726             2            0.250000           7           9
# 2737             2            0.266667           7           8
# 2769             3            0.272727          10          12
# 3149             4            0.296296           7          22
# 3486             3            0.285714           8          13
# 3969             3            0.285714           8          14
# 4135             3            0.222222          20           7
# 4603             1            0.125000           5          13
# 4730             2            0.250000           6          10
# 4817             2            0.285714           6           8
# 5271             3            0.230769          10          20
# 5459             3            0.285714          12           9
# 5647             5            0.294118          25          12
# 5799             3            0.272727          14           9
# 5860             3            0.222222          10          18
# 6123             4            0.285714          18          11
# 6360             2            0.285714           9           5
# 6447             2            0.285714           5           9
# 7280             1            0.064516          23          11
# 7403             2            0.266667           7           8
# 7438             5            0.294118          14          20
# 7575             3            0.260870          15           8
# 8458             4            0.266667          11          21
# 8585             3            0.250000          14          12
# 8693             3            0.260870           8          15
# 8856             4            0.296296          10          20
# 8965             4            0.258065          12          20
# 9746             4            0.242424          10          24
# 9949             2            0.166667           6          19
#
#                                                                            q1_synonym  \
# 380                    Is there any evidence that can turn out the beingness of God ?
# 701                         What is the best way to addition traffic for a new blog ?
# 1562                                          What is the best way to acquire cheat ?
# 1697                                            Why do I get hiccup when I eat rice ?
# 1930                                           How can you header with solitariness ?
# 1978                                       What works to brand a man 's penis thick ?
# 2075                                             How do I get rid of my stomach fat ?
# 2280      Why Do You think world War 3 will pass off ? I personally think it wo n't .
# 2368                             Who is presently winning the presidential election ?
# 2595                                                Did Mahabharata happen for real ?
# 2670  `` What Energy Department Donald trump mean when he say '' `` I am batman ''...
# 2726                                                    Is there any hacker for coc ?
# 2737                                               What are some instance of adverb ?
# 2769                                 What would be take for Gary Dr. Johnson to win ?
# 3149                                   How Energy Sonakshi Sinha get moving picture ?
# 3486                      How Department of Energy one get rich real number fasting ?
# 3969                             Is clip travelling possible through cosmic strings ?
# 4135  I am a mechanical technologist with no cognition of programming . What is th...
# 4603                                                       What be before beingness ?
# 4730                                                            How do I defeat OCD ?
# 4817                                    How can I get methylenedioxymethamphetamine ?
# 5271          In what medium Energy visible radiation -LRB- photon -RRB- travelling ?
# 5459  How do I download hotstar picture exploitation personal electronic computer ...
# 5647  `` Is it possible that Donald trump is candidacy very gravely '' `` on purpo...
# 5799   What are some good book or mention to get start out with machine acquisition ?
# 5860                             What are some times Gandalf as be altogether wrong ?
# 6123  What are the best indoor workout to remove venter fat whole and lose weight ...
# 6360                                               What 's the best way to get rich ?
# 6447                                              Energy Quora censor interrogation ?
# 7280  `` Why is it that the '' `` inside information '' '' box on Quora has such l...
# 7403                                        How do you train/improve your intuition ?
# 7438     How do I hack a WhatsApp chronicle without have admittance to victim phone ?
# 7575  What is the best way or resource to learn English the like a indigen verbali...
# 8458                                     How can I get into a vlsi start up company ?
# 8585                          Is it true goat will eat anything ? How do they do it ?
# 8693                                               How can I lose my weight fasting ?
# 8856                            How many straight woman have kip with another woman ?
# 8965                     What would be impact on India if Donald trump go president ?
# 9746                                Why Energy n't tesla use lidar in their machine ?
# 9949                                                    Why do exchange Banks exist ?
#
#                                                                            q2_synonym
# 380   Do you believe in a god ? If so , what variety of testable evidence do you h...
# 701                                            How do I increase traffic on my site ?
# 1562                                                 How do I play Bromus secalinus ?
# 1697           What cause hiccup after you eat and how can you rid yourself of them ?
# 1930                                          What are the ways to end solitariness ?
# 1978                               Can you brand your penis larger at the age of 27 ?
# 2075                            What is the best way to cut back venter and arm fat ?
# 2280                               What could potentially flicker existence War III ?
# 2368  All bias aside , at this point in clip , who do you think volition win the p...
# 2595  Is Mahabharata real number ? If it is , where are the nowadays contemporarie...
# 2670                                                How is Donald trump like batman ?
# 2726                                     How can I hack clank of kinship group game ?
# 2737                                          How do you Thatch nipper astir adverb ?
# 2769    How could Gary Samuel Johnson end up winning the 2016 presidential election ?
# 3149  Why is Sonakshi Sinha -LRB- not a good histrion , not very good looking and ...
# 3486                            rich people of Quora , what should I do to get rich ?
# 3969      Could clip traveling be a real thing ? Could it be scientifically explain ?
# 4135                                                How can I learn march on python ?
# 4603                          `` What was there before the '' `` beginning '' '' ? ''
# 4730                                        What is the best way to coping with OCD ?
# 4817                   What are some shipway to issue methylenedioxymethamphetamine ?
# 5271  `` If light is a moving ridge , what is the medium that is '' `` waving '' '...
# 5459                                    Is there any way to download hotstar serial ?
# 5647  Is Hillary Hilary Rodham Clinton on the Q.T. pay Donald trump card to throw ...
# 5799                             How should I go astir acquisition machine learning ?
# 5860  In The hobbit and Maker of the rings , when was Gandalf prove to be factuall...
# 6123                                      How can I lose stomach fat if I 'm skinny ?
# 6360                                                           Can I be rich people ?
# 6447                Why Energy Department Quora wealthy person no freedom of speech ?
# 7280      Why Energy Quora rich person a fictional character bound in query details ?
# 7403                                           What are some ways to gain intuition ?
# 7438  My WhatsApp has be hack by individual . How can she or he do it without acqu...
# 7575                                      How can I acquire English language well ？ ?
# 8458  What are the call for class in the field of VLSI that educatee must return t...
# 8585               What is the ground why caprine animal are able to eat everything ?
# 8693       Whats the most efficacious way / solution to lose weight in a short time ?
# 8856  `` How many straight woman wealthy person '' `` dip in the lady pond '' '' o...
# 8965  If Donald trump win the presidential election , how will the relationship be...
# 9746  Department of Energy the want of lidar put tesla at a disadvantage vs. other...
# 9949  What is the concept fundament formation of exchange Banks all across the cos...

# %%
score_dup = df_50k[(df_50k['word_overlap_score'] > 0.5) & (df_50k['is_duplicate'] == 0)].count()[0]
score_nondup = df_50k[(df_50k['word_overlap_score'] < 0.5) & (df_50k['is_duplicate'] == 1)].count()[0]
print(score_dup)
print(score_nondup)
# Out:
# 12263
# 3841

# %%
df_50k[(df_50k['word_overlap_score'] > 0.6) & (df_50k['is_duplicate'] == 0)].count()[0]
# Out:
# 9172

# %%
df_50k[(df_10k['word_overlap_score'] < 0.4)& (df_50k['is_duplicate'] == 1)].count()[0]
# Out:
# 1150

# %%
overlap_10k = df_10k[(df_10k['word_overlap_score'] > 0.6)]
overlap_10k = overlap_10k[['is_duplicate','question2', 'question1', 'id']]
overlap_10k.rename(columns={'question2':'question1',
                            'question1':'question2'}, inplace=True)

low_overlap_10k = df_10k[(df_10k['word_overlap_score'] < 0.4) & (df_10k['is_duplicate'] == 1)]
low_overlap_10k = low_overlap_10k[['is_duplicate','question2', 'question1', 'id']]
low_overlap_10k.rename(columns={'question2':'question1',
                            'question1':'question2'}, inplace=True)

heuristic_10k = pd.concat([df_10k[['is_duplicate','question1', 'question2', 'id']], overlap_10k, low_overlap_10k])
heuristic_10k.groupby('is_duplicate').count()
# Out:
#               question1  question2    id
# is_duplicate
# 0                  8172       8172  8172
# 1                  6021       6021  6021

# %%
overlap_50k = df_50k[(df_50k['word_overlap_score'] > 0.6)]
overlap_50k = overlap_50k[['is_duplicate','question2', 'question1', 'id']]
overlap_50k.rename(columns={'question2':'question1',
                            'question1':'question2'}, inplace=True)

low_overlap_50k = df_50k[(df_50k['word_overlap_score'] < 0.4) & (df_50k['is_duplicate'] == 1)]
low_overlap_50k = low_overlap_50k[['is_duplicate','question2', 'question1', 'id']]
low_overlap_50k.rename(columns={'question2':'question1',
                            'question1':'question2'}, inplace=True)

heuristic_50k = pd.concat([df_50k[['is_duplicate','question1', 'question2', 'id']], overlap_50k, low_overlap_50k])
heuristic_50k.groupby('is_duplicate').count()
# Out:
#               question1  question2     id
# is_duplicate
# 0                 41114      41114  41114
# 1                 29930      29930  29930

# %%
print(heuristic_10k.count()[0])
print(heuristic_50k.count()[0])
# Out:
# 14678
# 73416

# %%
heuristic_10k.to_csv('heuristic_10k.tsv',sep='\t', header=False, index=False, encoding='utf-8')
heuristic_50k.to_csv('heuristic_50k.tsv',sep='\t', header=False, index=False, encoding='utf-8')

# %% [markdown]
# # REPLACE SYNONYMS - THESAURUS BASED AUGMENTATION

# %%
def replace_sysnonyms(text):
    line = text.strip()
    words = line.split(" ")
    output = list()
    for word_str in words:
        word_obj = Word(word_str)
        if len(word_str) > 3 and len(word_obj.synsets) > 0:
            synset = word_obj.synsets[0]
            lemma = random.choice(synset.lemma_names())
            output.append(lemma.replace('_', ' '))
        else:
            output.append(word_str)
    new_text =  " ".join(output)
    return new_text

# %%
df_10k['q1_synonym'] = df_10k['question1'].apply(lambda x: replace_sysnonyms(x))
df_10k['q2_synonym'] = df_10k['question2'].apply(lambda x: replace_sysnonyms(x))

df_50k['q1_synonym'] = df_50k['question1'].apply(lambda x: replace_sysnonyms(x))
df_50k['q2_synonym'] = df_50k['question2'].apply(lambda x: replace_sysnonyms(x))

# %%
# df_10k[['question1', 'q1_synonym','question2', 'q2_synonym']]
synonyms_10k = df_10k[['is_duplicate','q1_synonym', 'q2_synonym', 'id']]
synonyms_10k.rename(columns={'q1_synonym':'question1',
                            'q2_synonym':'question2'}, inplace=True)
df_10k_syn = pd.concat([df_10k[['is_duplicate','question1', 'question2', 'id']], synonyms_10k])
# Out:
# /Users/andrada/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3778: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
synonyms_10k
# Out:
#       is_duplicate  \
# 0                0
# 1                0
# 2                0
# 3                1
# 4                1
# 5                0
# 6                0
# 7                0
# 8                0
# 9                0
# 10               0
# 11               1
# 12               0
# 13               0
# 14               0
# 15               0
# 16               0
# 17               0
# 18               0
# 19               0
# 20               0
# 21               0
# 22               0
# 23               1
# 24               1
# 25               1
# 26               1
# 27               1
# 28               0
# 29               1
# ...            ...
# 9970             0
# 9971             0
# 9972             0
# 9973             0
# 9974             0
# 9975             1
# 9976             1
# 9977             0
# 9978             0
# 9979             0
# 9980             0
# 9981             1
# 9982             0
# 9983             0
# 9984             0
# 9985             0
# 9986             0
# 9987             1
# 9988             0
# 9989             1
# 9990             0
# 9991             0
# 9992             0
# 9993             1
# 9994             0
# 9995             0
# 9996             0
# 9997             0
# 9998             0
# 9999             0
#
#                                                         question1  \
# 0     Should mandarin course of study be present in the school...
# 1     How many people could get millionaire this twelvemonth  ...
# 2     What are good gift for a foreign visitant to take when t...
# 3                          How do you in good order tie ice skate
# 4                     acquiring start out on Quora  What is Quora
# 5                                   What is the name of this song
# 6                             What are the dealing charge of BHIM
# 7                          What will be the futurity of hereafter
# 8                                    Can hummingbird fly backward
# 9        Do diet coke and coke naught really have nix kilocalorie
# 10    How volition the hereafter of mechanical engineer in mac...
# 11               What are the best Web designing company s in USA
# 12    What would be a better choice to movie for entertainment...
# 13           A comparing between North Korea and the soviet union
# 14    Who privation will composition services at Southen on se...
# 15                Which are top 10 strong gird force in macrocosm
# 16    Why do gay people argue that their behavior is normal wh...
# 17    If you natural a Facebook friend postulation  Energy the...
# 18    Am I the lone one who think Rachel viridity is a bitch i...
# 19                      Which are the best SIP to place in Bharat
# 20    rich person you ever change your political belief becaus...
# 21                 How gummy can football game mitt be in the NFL
# 22    What is the Hong Kong equivalent of Polipay in Australia...
# 23    What s the best pic you wealthy person take on an iPhone...
# 24    What volition be the impact of ban of 500 rupee and 1000...
# 25         What can I get efficient at mathematics job resolution
# 26           How can I get a passport without a birth credentials
# 27           How do you add topic upon asking a question on Quora
# 28    How do I rank the latest dwell update content in Google ...
# 29                             How do I know what stock to put in
# ...                                                           ...
# 9970                           How did you defeat your depression
# 9971  I want to physique one matrimony hall in my land  how do...
# 9972                              Why do rabbit like to eat paper
# 9973  What is the typical vocation way for individual who get ...
# 9974                   How a missy can impressment a maturate boy
# 9975  Was today s UPSC front matter 2016 a street fighter pape...
# 9976                                     How good is the iPhone 6
# 9977           Is it bad I grin when I see people I dont the like
# 9978                               How can I acquire cryptography
# 9979  How ofttimes Energy Department Netflix add new statute t...
# 9980  Who will win in AC Milan VS Chelsea International title-...
# 9981  Why is there an evident increase of mass shooting in the US
# 9982                            What do I do about a bug in Quora
# 9983                 Why Energy Department an climax feel so good
# 9984  Why do employer sometimes place ads for position they ve...
# 9985              How do the gyro in smartness telephone set work
# 9986  What are the world most crazy disbursement of any indivi...
# 9987  If you be to set up a res publica  what would it express...
# 9988                                       Is Die hard a Yule pic
# 9989        How can a outlander become a instructor in the States
# 9990  If you are deploy on a US pigboat and a conclusion relat...
# 9991  What song should I listen to  larn  or dramatic play on ...
# 9992                               How do I sleep naked in hostel
# 9993      What s the best twitter direction programme or software
# 9994     Why is Google chrome running play slow down on my tablet
# 9995         What is the assessment valuation system in Capgemini
# 9996  Which actoractress seem to be Max Born to play a particu...
# 9997                         What make Pablo Picasso so legendary
# 9998  What is the difference in Kruskal s and prim s algorithm...
# 9999  What should all Indian professional person know astir ex...
#
#                                                         question2      id
# 0     How do I get a digital marketingSales job in Hong Kong  ...   45324
# 1     start with nil at all  how many old age Energy Departmen...  263521
# 2     What are good gift for a foreign visitant to convey when...  246571
# 3                      How can I tie my ice skate shoelace decent  313078
# 4                                           Who and what is Quora  239251
# 5                                    What s the name of this song  158495
# 6     Are the state bank associate s proceedings available on ...   93832
# 7                                               What is my future  364295
# 8                                 How do hummingbird fly rearward  346488
# 9     volition coke cypher or coke visible radiation make me p...  387336
# 10    I wealthy person a unmarried man in mechanical engineeri...  373177
# 11                         What best web designing company in USA    7880
# 12    Are cosmonaut offer special entertainment privilege  the...  345270
# 13                How do you cancel a Zoosk history from a Mobile  296788
# 14    will those who purchase at low involvement rates  but hi...  185746
# 15                           How strong is the Canadian arm force   48846
# 16    If the main intent of all being is to reproduce and repr...   64177
# 17         How to natural all friend petition pending on Facebook  209619
# 18    If I care dexter  Hannibal and break Bad  what show shou...  210751
# 19                             Which is the best SIP to invest in  115753
# 20    On Quora  wealthy person you of all time had a down vote...  166813
# 21    DOE POTUS get a lifetime pass to all NFL football game game   98400
# 22      What is it like to work in investing banking in Hong Kong  393872
# 23             What are the best exposure you have take by Mobile  178651
# 24    What volition be the impact of the ban grand and 500 in ...  231536
# 25    What can I do to go efficient at resolution mathematics job  330125
# 26                    How do I get pass without birth credentials   16882
# 27                              How do I add all subject in Quora  294889
# 28    fast path from kengeri to new sensible horizon engineeri...   45304
# 29                How do people pick out what stocks to commit in  173677
# ...                                                           ...     ...
# 9970                               How did I defeat my depression  125514
# 9971  Which are the major highway in California and how are th...   51738
# 9972                                           What do rabbit eat  347914
# 9973  What is the typical vocation way for mortal who get a pr...  361257
# 9974                                How DOE a fille impress a boy  146822
# 9975                                    How was upsc prelims 2016  201121
# 9976                                         Is the iPhone 6 good  323561
# 9977      What do both Gaara and Naruto wealthy person in commons  341873
# 9978  How can I larn and pattern secret writing  I want to cod...  311328
# 9979                 How do I add Netflix to my Xbox lame profile  300414
# 9980  Who volition win in Liverpool VS AC Milan International ...  205561
# 9981        Why do you think there are so many shooting in the US  269728
# 9982                               How can I study a bug on Quora  149037
# 9983  What DOE it feel the likes of for a woman to have an climax  295359
# 9984  I m with a company for 2 calendar month already  withal ...  291480
# 9985                        How do I use a smart telephone safely  373148
# 9986  What are the comic  unbalanced and most unequaled slipwa...  301522
# 9987  If you could create a nation  what would it be the likes of   86120
# 9988                   Why do people say Die hard is a Noel flick  226536
# 9989                 How can a noncitizen go a teacher in the USA  200765
# 9990  If you come patch flight a supersonic jet and the residu...  400569
# 9991          What song should I larn to dramatic play on the uke   37675
# 9992                                    How do I sleep au naturel  342370
# 9993                    What is the chirrup story manager package  356704
# 9994   Why is Google chrome running play decelerate on my android  187851
# 9995  What is the demand earnings offer by Capgemini to freshm...  310572
# 9996  playacting  What are the most intense things an thespian...  391249
# 9997  Do you think an lineman for Pablo Picasso steal Pablo Pi...   70218
# 9998  What real universe application of the Kruskal algorithm ...  135698
# 9999              How Energy Department humanity obtain knowledge  385167
#
# [10000 rows x 4 columns]

# %%
synonyms_50k = df_50k[['is_duplicate','q1_synonym', 'q2_synonym', 'id']]
synonyms_50k.rename(columns={'q1_synonym':'question1',
                            'q2_synonym':'question2'}, inplace=True)
df_50k_syn = pd.concat([df_50k[['is_duplicate','question1', 'question2', 'id']], synonyms_50k])
# Out:
# /Users/andrada/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3778: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
df_10k_syn.to_csv('synonyms_10k.tsv',sep='\t', header=False, index=False, encoding='utf-8')
df_50k_syn.to_csv('synonyms_50k.tsv',sep='\t', header=False, index=False, encoding='utf-8')

# %% [markdown]
# # REVERSE QUESTION ORDER

# %%
reverse_10k = df_10k[['is_duplicate','question2', 'question1', 'id']]
reverse_10k.rename(columns={'question2':'question1',
                            'question1':'question2'}, inplace=True)
reverse_10k.head()
df_reverse_10k = pd.concat([df_10k[['is_duplicate','question1', 'question2', 'id']], reverse_10k])
df_reverse_10k.head()
# Out:
#    is_duplicate                                          question1  \
# 0             0  Should Mandarin course be introduced in the sc...
# 1             0  How many people could become millionaires this...
# 2             0  What are good gifts for a foreign visitor to b...
# 3             1               How do you properly tie ice skates ?
# 4             1         Getting Started on Quora : What is Quora ?
#
#                                            question2      id
# 0  How do I get a Digital marketing/Sales job in ...   45324
# 1  Starting with nothing at all , how many years ...  263521
# 2  What are good gifts for a foreign visitor to b...  246571
# 3    How can I tie my ice skate shoelaces properly ?  313078
# 4                            Who and what is Quora ?  239251

# %%
reverse_50k = df_50k[['is_duplicate','question2', 'question1', 'id']]
reverse_50k.rename(columns={'question2':'question1',
                            'question1':'question2'}, inplace=True)
reverse_50k.head()
df_reverse_50k = pd.concat([df_50k[['is_duplicate','question1', 'question2', 'id']], reverse_50k])
df_reverse_50k.count()
# Out:
# is_duplicate    100000
# question1       100000
# question2       100000
# id              100000
# dtype: int64

# %%
df_reverse_10k.to_csv('reverse_10k.tsv',sep='\t', header=False, index=False, encoding='utf-8')
df_reverse_50k.to_csv('reverse_50k.tsv',sep='\t', header=False, index=False, encoding='utf-8')

# %%
df_10k[['is_duplicate','question1', 'question2', 'id']].head(15)
# Out:
#     is_duplicate                                                    question1  \
# 0              0  Should Mandarin course be introduced in the schools ? Is...
# 1              0  How many people could become millionaires this year , th...
# 2              0  What are good gifts for a foreign visitor to bring when ...
# 3              1                         How do you properly tie ice skates ?
# 4              1                   Getting Started on Quora : What is Quora ?
# 5              0                              What is the name of this song ?
# 6              0                   What are the transaction charges of BHIM ?
# 7              0                          What will be the future of future ?
# 8              0                             Can hummingbirds fly backwards ?
# 9              0       Do Diet Coke and Coke Zero really have zero calories ?
# 10             0  How will the future of mechanical engineer in machine se...
# 11             1          What are the best Web designing company 's in USA ?
# 12             0  What would be a better alternative to movies for enterta...
# 13             0      A comparison between north korea and the soviet union ?
# 14             0  Who wants will writing services at Southen on sea , UK v...
#
#                                                       question2      id
# 0   How do I get a Digital marketing/Sales job in Hong Kong ...   45324
# 1   Starting with nothing at all , how many years does it ta...  263521
# 2   What are good gifts for a foreign visitor to bring when ...  246571
# 3               How can I tie my ice skate shoelaces properly ?  313078
# 4                                       Who and what is Quora ?  239251
# 5                               What 's the name of this song ?  158495
# 6   Are the State Bank associates 's transactions available ...   93832
# 7                                           What is my future ?  364295
# 8                           How do hummingbirds fly backwards ?  346488
# 9          Will Coke Zero or Coke Light make me put on weight ?  387336
# 10  I have a bachelor in Mechanical Engineering . Considerin...  373177
# 11                        What Best web design company in USA ?    7880
# 12  Are astronauts offered special entertainment privileges ...  345270
# 13            How do you delete a Zoosk account from a mobile ?  296788
# 14  Will those who bought at low interest rates , but higher...  185746
